# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cleaned/cleaned_dataset.csv

# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 45.8 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import pandas as pd
from pyts.image import MarkovTransitionField
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import warnings
from collections import Counter
import gc
from tensorflow.keras import backend as K

warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/kaggle/input/cleaned/cleaned_dataset.csv')  # Replace with your path
df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.sort_values(['SubjectID', 'DateTime'])

# Preprocess features
feature_cols = ['AccX', 'AccY', 'AccZ', 'Temp', 'EDA', 'HeartRate', 'SpO2']
target_col = 'Label'

scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

def create_windows(df, feature_cols, target_col, window_size=100, step=20):
    X = []
    y = []
    for subject_id, subject_df in df.groupby('SubjectID'):
        subject_data = subject_df.reset_index(drop=True)
        features = subject_data[feature_cols].values
        labels = subject_data[target_col].values
        for start in range(0, len(features) - window_size, step):
            end = start + window_size
            window_x = features[start:end]
            window_y = labels[start:end]
            label = Counter(window_y).most_common(1)[0][0]
            X.append(window_x)
            y.append(label)
    return np.array(X), np.array(y)

X, y = create_windows(df, feature_cols, target_col)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Convert time-series to images using MTF
def time_series_to_image_mtf(sample, image_size=64):
    mtf = MarkovTransitionField(image_size=image_size)
    img_list = []
    for i in range(sample.shape[1]):
        ts = sample[:, i]
        img = mtf.fit_transform(ts.reshape(1, -1))[0]
        img_list.append(img)
    img = np.stack(img_list, axis=-1)
    return img

image_data = np.array([time_series_to_image_mtf(seq) for seq in X])

# CNN model
def build_image_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Evaluation
def evaluate_model(model, X_test, y_test, label_encoder, title="Model"):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    specificity_per_class = []
    for i in range(len(cm)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(np.delete(cm, i, axis=0)[:, i])
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        specificity_per_class.append(specificity)
    weighted_specificity = np.average(specificity_per_class, weights=np.bincount(y_true_classes))

    print(f"\n{title}")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"F1 Score     : {f1:.4f}")
    print(f"Specificity  : {weighted_specificity:.4f}")

    return accuracy, precision, recall, f1, weighted_specificity

# LOSO Classification with memory clearing
results_loso = {}
subject_ids = df['SubjectID'].unique()

for test_subject in subject_ids:
    print(f"\n--- Evaluating on Subject {test_subject} ---")
    
    train_subjects = df[df['SubjectID'] != test_subject]
    test_subject_df = df[df['SubjectID'] == test_subject]
    
    X_train_loso, y_train_loso = create_windows(train_subjects, feature_cols, target_col)
    X_test_loso, y_test_loso = create_windows(test_subject_df, feature_cols, target_col)

    image_data_train = np.array([time_series_to_image_mtf(seq) for seq in X_train_loso])
    image_data_test = np.array([time_series_to_image_mtf(seq) for seq in X_test_loso])

    y_train_cat = to_categorical(le.transform(y_train_loso))
    y_test_cat = to_categorical(le.transform(y_test_loso))

    img_model_loso = build_image_model(image_data_train.shape[1:], y_cat.shape[1])
    img_model_loso.fit(image_data_train, y_train_cat,
                       validation_data=(image_data_test, y_test_cat),
                        epochs=15, batch_size=32)

    acc, precision, recall, f1, specificity = evaluate_model(
        img_model_loso, image_data_test, y_test_cat, le, title=f"Test Subject {test_subject}"
    )
    
    results_loso[test_subject] = {
        'Accuracy': acc,
        'Precision': precision,
        'Recall': recall,
        'F1': f1,
        'Specificity': specificity
    }
    # Save model for this subject
    model_path = f"/kaggle/working/loso_model_subject_{test_subject}.h5"
    img_model_loso.save(model_path)
    print(f"Saved model for Subject {test_subject} to {model_path}")
    # Clear memory
    K.clear_session()
    gc.collect()
    del img_model_loso, image_data_train, image_data_test, X_train_loso, X_test_loso, y_train_loso, y_test_loso, y_train_cat, y_test_cat

# Summary of results
print("\n=== LOSO Evaluation Summary ===")
print("Average Accuracy    :", np.mean([res['Accuracy'] for res in results_loso.values()]))
print("Average Precision   :", np.mean([res['Precision'] for res in results_loso.values()]))
print("Average Recall      :", np.mean([res['Recall'] for res in results_loso.values()]))
print("Average F1 Score    :", np.mean([res['F1'] for res in results_loso.values()]))
print("Average Specificity :", np.mean([res['Specificity'] for res in results_loso.values()]))

# Save LOSO Results
with open("loso_results.txt", "w") as f:
    f.write("=== LOSO Evaluation Results ===\n\n")
    for subject_id, metrics in results_loso.items():
        f.write(f"Test Subject {subject_id}:\n")
        for metric_name, metric_value in metrics.items():
            f.write(f"  {metric_name}: {metric_value:.4f}\n")
        f.write("\n")

    f.write("=== Average LOSO Metrics ===\n")
    f.write(f"Accuracy     : {np.mean([res['Accuracy'] for res in results_loso.values()]):.4f}\n")
    f.write(f"Precision    : {np.mean([res['Precision'] for res in results_loso.values()]):.4f}\n")
    f.write(f"Recall       : {np.mean([res['Recall'] for res in results_loso.values()]):.4f}\n")
    f.write(f"F1 Score     : {np.mean([res['F1'] for res in results_loso.values()]):.4f}\n")
    f.write(f"Specificity  : {np.mean([res['Specificity'] for res in results_loso.values()]):.4f}\n")
# Out:
# 2025-04-14 16:28:05.089341: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744648085.334899      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744648085.411114      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Evaluating on Subject Subject1 ---
# 2025-04-14 16:32:14.871488: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 85s 144ms/step - accuracy: 0.6260 - loss: 0.9513 - val_accuracy: 0.6964 - val_loss: 0.8079
# Epoch 2/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.6936 - loss: 0.7932 - val_accuracy: 0.6650 - val_loss: 0.7987
# Epoch 3/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7064 - loss: 0.7551 - val_accuracy: 0.6954 - val_loss: 0.7342
# Epoch 4/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7140 - loss: 0.7240 - val_accuracy: 0.7107 - val_loss: 0.7121
# Epoch 5/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7179 - loss: 0.7051 - val_accuracy: 0.7046 - val_loss: 0.6858
# Epoch 6/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7216 - loss: 0.6974 - val_accuracy: 0.6995 - val_loss: 0.7073
# Epoch 7/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7301 - loss: 0.6642 - val_accuracy: 0.6863 - val_loss: 0.7590
# Epoch 8/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7402 - loss: 0.6545 - val_accuracy: 0.7076 - val_loss: 0.7130
# Epoch 9/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7429 - loss: 0.6391 - val_accuracy: 0.6893 - val_loss: 0.7333
# Epoch 10/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7413 - loss: 0.6311 - val_accuracy: 0.7036 - val_loss: 0.7178
# Epoch 11/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7512 - loss: 0.6194 - val_accuracy: 0.6345 - val_loss: 0.9058
# Epoch 12/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7518 - loss: 0.6075 - val_accuracy: 0.7076 - val_loss: 0.7108
# Epoch 13/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7536 - loss: 0.5966 - val_accuracy: 0.7056 - val_loss: 0.7222
# Epoch 14/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7581 - loss: 0.5844 - val_accuracy: 0.7117 - val_loss: 0.6999
# Epoch 15/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 79s 141ms/step - accuracy: 0.7654 - loss: 0.5683 - val_accuracy: 0.7188 - val_loss: 0.6618
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# Test Subject Subject1
# Accuracy     : 0.7188
# Precision    : 0.7062
# Recall       : 0.7188
# F1 Score     : 0.7036
# Specificity  : 0.7953
# Saved model for Subject Subject1 to /kaggle/working/loso_model_subject_Subject1.h5
#
# --- Evaluating on Subject Subject10 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 143ms/step - accuracy: 0.5930 - loss: 1.0182 - val_accuracy: 0.7456 - val_loss: 0.7213
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.6875 - loss: 0.8073 - val_accuracy: 0.7236 - val_loss: 0.7407
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.6937 - loss: 0.7631 - val_accuracy: 0.7654 - val_loss: 0.6612
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7122 - loss: 0.7229 - val_accuracy: 0.7621 - val_loss: 0.7123
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7175 - loss: 0.7010 - val_accuracy: 0.7720 - val_loss: 0.6172
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7235 - loss: 0.6825 - val_accuracy: 0.7203 - val_loss: 0.7089
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7200 - loss: 0.6843 - val_accuracy: 0.7874 - val_loss: 0.6315
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7284 - loss: 0.6674 - val_accuracy: 0.7687 - val_loss: 0.6633
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7356 - loss: 0.6439 - val_accuracy: 0.7896 - val_loss: 0.6037
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7446 - loss: 0.6317 - val_accuracy: 0.7885 - val_loss: 0.6560
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7446 - loss: 0.6166 - val_accuracy: 0.7941 - val_loss: 0.6340
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 143ms/step - accuracy: 0.7510 - loss: 0.6133 - val_accuracy: 0.7863 - val_loss: 0.6098
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7559 - loss: 0.5948 - val_accuracy: 0.7533 - val_loss: 0.6799
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7554 - loss: 0.5863 - val_accuracy: 0.7819 - val_loss: 0.5977
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7572 - loss: 0.5701 - val_accuracy: 0.7963 - val_loss: 0.5850
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
#
# Test Subject Subject10
# Accuracy     : 0.7963
# Precision    : 0.7980
# Recall       : 0.7963
# F1 Score     : 0.7939
# Specificity  : 0.9132
# Saved model for Subject Subject10 to /kaggle/working/loso_model_subject_Subject10.h5
#
# --- Evaluating on Subject Subject11 ---
# Epoch 1/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 83s 143ms/step - accuracy: 0.6369 - loss: 0.9254 - val_accuracy: 0.5752 - val_loss: 1.0489
# Epoch 2/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 80s 143ms/step - accuracy: 0.7016 - loss: 0.7752 - val_accuracy: 0.5866 - val_loss: 1.0644
# Epoch 3/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7168 - loss: 0.7207 - val_accuracy: 0.6033 - val_loss: 1.0002
# Epoch 4/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7163 - loss: 0.7132 - val_accuracy: 0.5778 - val_loss: 1.0970
# Epoch 5/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7197 - loss: 0.6963 - val_accuracy: 0.6007 - val_loss: 1.0428
# Epoch 6/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7362 - loss: 0.6643 - val_accuracy: 0.5840 - val_loss: 1.1957
# Epoch 7/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 79s 141ms/step - accuracy: 0.7323 - loss: 0.6686 - val_accuracy: 0.5611 - val_loss: 1.1075
# Epoch 8/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7450 - loss: 0.6356 - val_accuracy: 0.6033 - val_loss: 1.1347
# Epoch 9/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 79s 141ms/step - accuracy: 0.7473 - loss: 0.6254 - val_accuracy: 0.5620 - val_loss: 1.0410
# Epoch 10/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7518 - loss: 0.6189 - val_accuracy: 0.5805 - val_loss: 1.1778
# Epoch 11/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7546 - loss: 0.6171 - val_accuracy: 0.5937 - val_loss: 1.1626
# Epoch 12/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 80s 143ms/step - accuracy: 0.7655 - loss: 0.5794 - val_accuracy: 0.5840 - val_loss: 1.1030
# Epoch 13/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7812 - loss: 0.5440 - val_accuracy: 0.5928 - val_loss: 1.0573
# Epoch 14/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7812 - loss: 0.5389 - val_accuracy: 0.6033 - val_loss: 1.0317
# Epoch 15/15
# 561/561 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.8011 - loss: 0.4995 - val_accuracy: 0.5884 - val_loss: 1.0490
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
#
# Test Subject Subject11
# Accuracy     : 0.5884
# Precision    : 0.5509
# Recall       : 0.5884
# F1 Score     : 0.5350
# Specificity  : 0.6787
# Saved model for Subject Subject11 to /kaggle/working/loso_model_subject_Subject11.h5
#
# --- Evaluating on Subject Subject12 ---
# Epoch 1/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 85s 145ms/step - accuracy: 0.6194 - loss: 0.9532 - val_accuracy: 0.7373 - val_loss: 0.7290
# Epoch 2/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.6916 - loss: 0.7920 - val_accuracy: 0.7568 - val_loss: 0.7100
# Epoch 3/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 141s 145ms/step - accuracy: 0.7019 - loss: 0.7506 - val_accuracy: 0.7514 - val_loss: 0.6691
# Epoch 4/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7135 - loss: 0.7160 - val_accuracy: 0.7438 - val_loss: 0.6949
# Epoch 5/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7197 - loss: 0.7028 - val_accuracy: 0.7449 - val_loss: 0.6554
# Epoch 6/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7232 - loss: 0.6850 - val_accuracy: 0.7524 - val_loss: 0.6385
# Epoch 7/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7325 - loss: 0.6542 - val_accuracy: 0.7481 - val_loss: 0.6337
# Epoch 8/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7374 - loss: 0.6517 - val_accuracy: 0.7384 - val_loss: 0.6521
# Epoch 9/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7434 - loss: 0.6339 - val_accuracy: 0.7470 - val_loss: 0.6493
# Epoch 10/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7459 - loss: 0.6239 - val_accuracy: 0.7351 - val_loss: 0.6738
# Epoch 11/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7482 - loss: 0.6003 - val_accuracy: 0.7405 - val_loss: 0.6411
# Epoch 12/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7592 - loss: 0.5844 - val_accuracy: 0.7578 - val_loss: 0.6299
# Epoch 13/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7669 - loss: 0.5604 - val_accuracy: 0.7416 - val_loss: 0.6364
# Epoch 14/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.7834 - loss: 0.5347 - val_accuracy: 0.7676 - val_loss: 0.6165
# Epoch 15/15
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 142s 145ms/step - accuracy: 0.7960 - loss: 0.5067 - val_accuracy: 0.7827 - val_loss: 0.5699
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
#
# Test Subject Subject12
# Accuracy     : 0.7827
# Precision    : 0.7743
# Recall       : 0.7827
# F1 Score     : 0.7721
# Specificity  : 0.8469
# Saved model for Subject Subject12 to /kaggle/working/loso_model_subject_Subject12.h5
#
# --- Evaluating on Subject Subject13 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 145ms/step - accuracy: 0.6323 - loss: 0.9375 - val_accuracy: 0.7126 - val_loss: 0.7125
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.6901 - loss: 0.7982 - val_accuracy: 0.7423 - val_loss: 0.6590
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 143ms/step - accuracy: 0.7047 - loss: 0.7433 - val_accuracy: 0.7280 - val_loss: 0.6630
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7095 - loss: 0.7148 - val_accuracy: 0.7269 - val_loss: 0.6082
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7204 - loss: 0.6999 - val_accuracy: 0.7346 - val_loss: 0.6254
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7249 - loss: 0.6696 - val_accuracy: 0.7280 - val_loss: 0.5969
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7318 - loss: 0.6579 - val_accuracy: 0.7247 - val_loss: 0.6762
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 146ms/step - accuracy: 0.7348 - loss: 0.6524 - val_accuracy: 0.7577 - val_loss: 0.5623
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7391 - loss: 0.6385 - val_accuracy: 0.7467 - val_loss: 0.5741
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7459 - loss: 0.6193 - val_accuracy: 0.7434 - val_loss: 0.6032
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7517 - loss: 0.6039 - val_accuracy: 0.7390 - val_loss: 0.6559
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7580 - loss: 0.5915 - val_accuracy: 0.7522 - val_loss: 0.6014
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7624 - loss: 0.5732 - val_accuracy: 0.7522 - val_loss: 0.5934
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7780 - loss: 0.5462 - val_accuracy: 0.7599 - val_loss: 0.5697
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7745 - loss: 0.5509 - val_accuracy: 0.7665 - val_loss: 0.5443
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
#
# Test Subject Subject13
# Accuracy     : 0.7665
# Precision    : 0.7516
# Recall       : 0.7665
# F1 Score     : 0.7458
# Specificity  : 0.8256
# Saved model for Subject Subject13 to /kaggle/working/loso_model_subject_Subject13.h5
#
# --- Evaluating on Subject Subject14 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 144ms/step - accuracy: 0.6292 - loss: 0.9436 - val_accuracy: 0.6935 - val_loss: 0.7361
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 145ms/step - accuracy: 0.6951 - loss: 0.7910 - val_accuracy: 0.7332 - val_loss: 0.6254
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7028 - loss: 0.7541 - val_accuracy: 0.7420 - val_loss: 0.6176
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 145ms/step - accuracy: 0.7219 - loss: 0.7080 - val_accuracy: 0.7607 - val_loss: 0.5722
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 143ms/step - accuracy: 0.7195 - loss: 0.6966 - val_accuracy: 0.7883 - val_loss: 0.5442
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7319 - loss: 0.6749 - val_accuracy: 0.7817 - val_loss: 0.5434
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 143ms/step - accuracy: 0.7381 - loss: 0.6533 - val_accuracy: 0.7949 - val_loss: 0.5602
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7312 - loss: 0.6516 - val_accuracy: 0.7883 - val_loss: 0.5582
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 146ms/step - accuracy: 0.7390 - loss: 0.6327 - val_accuracy: 0.7927 - val_loss: 0.5362
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7463 - loss: 0.6226 - val_accuracy: 0.7960 - val_loss: 0.5078
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7511 - loss: 0.6047 - val_accuracy: 0.7685 - val_loss: 0.5541
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7621 - loss: 0.5865 - val_accuracy: 0.8004 - val_loss: 0.5041
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7733 - loss: 0.5562 - val_accuracy: 0.8004 - val_loss: 0.4925
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7905 - loss: 0.5173 - val_accuracy: 0.8159 - val_loss: 0.4585
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.8141 - loss: 0.4705 - val_accuracy: 0.8467 - val_loss: 0.3956
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject14
# Accuracy     : 0.8467
# Precision    : 0.8482
# Recall       : 0.8467
# F1 Score     : 0.8373
# Specificity  : 0.8903
# Saved model for Subject Subject14 to /kaggle/working/loso_model_subject_Subject14.h5
#
# --- Evaluating on Subject Subject15 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 143ms/step - accuracy: 0.6197 - loss: 0.9653 - val_accuracy: 0.6807 - val_loss: 0.7496
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.6889 - loss: 0.7994 - val_accuracy: 0.7260 - val_loss: 0.6630
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7030 - loss: 0.7513 - val_accuracy: 0.7304 - val_loss: 0.6503
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7148 - loss: 0.7193 - val_accuracy: 0.7470 - val_loss: 0.6300
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7185 - loss: 0.6972 - val_accuracy: 0.7436 - val_loss: 0.6349
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 144s 148ms/step - accuracy: 0.7193 - loss: 0.6916 - val_accuracy: 0.7558 - val_loss: 0.5940
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7338 - loss: 0.6578 - val_accuracy: 0.7878 - val_loss: 0.5709
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7377 - loss: 0.6504 - val_accuracy: 0.7757 - val_loss: 0.5600
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7357 - loss: 0.6365 - val_accuracy: 0.7834 - val_loss: 0.5469
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7535 - loss: 0.6091 - val_accuracy: 0.7989 - val_loss: 0.5467
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 147ms/step - accuracy: 0.7634 - loss: 0.5852 - val_accuracy: 0.7569 - val_loss: 0.5653
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7667 - loss: 0.5751 - val_accuracy: 0.7812 - val_loss: 0.5195
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7791 - loss: 0.5520 - val_accuracy: 0.8166 - val_loss: 0.4615
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7989 - loss: 0.5042 - val_accuracy: 0.8884 - val_loss: 0.3357
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.8282 - loss: 0.4406 - val_accuracy: 0.8906 - val_loss: 0.3319
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject15
# Accuracy     : 0.8906
# Precision    : 0.8999
# Recall       : 0.8906
# F1 Score     : 0.8928
# Specificity  : 0.9560
# Saved model for Subject Subject15 to /kaggle/working/loso_model_subject_Subject15.h5
#
# --- Evaluating on Subject Subject16 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 86s 146ms/step - accuracy: 0.6103 - loss: 0.9714 - val_accuracy: 0.6874 - val_loss: 0.7643
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.6898 - loss: 0.8011 - val_accuracy: 0.7541 - val_loss: 0.6440
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7027 - loss: 0.7619 - val_accuracy: 0.7497 - val_loss: 0.6471
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7100 - loss: 0.7394 - val_accuracy: 0.7836 - val_loss: 0.6368
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7131 - loss: 0.7114 - val_accuracy: 0.7836 - val_loss: 0.6563
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.7227 - loss: 0.6847 - val_accuracy: 0.7814 - val_loss: 0.6886
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 149ms/step - accuracy: 0.7274 - loss: 0.6713 - val_accuracy: 0.7760 - val_loss: 0.6418
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.7438 - loss: 0.6464 - val_accuracy: 0.7672 - val_loss: 0.6851
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7418 - loss: 0.6402 - val_accuracy: 0.7803 - val_loss: 0.6514
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7446 - loss: 0.6245 - val_accuracy: 0.7738 - val_loss: 0.6995
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 150ms/step - accuracy: 0.7559 - loss: 0.6125 - val_accuracy: 0.7836 - val_loss: 0.6510
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7509 - loss: 0.6046 - val_accuracy: 0.7847 - val_loss: 0.6520
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 146s 152ms/step - accuracy: 0.7575 - loss: 0.5885 - val_accuracy: 0.7989 - val_loss: 0.6329
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7640 - loss: 0.5713 - val_accuracy: 0.7902 - val_loss: 0.7019
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7803 - loss: 0.5417 - val_accuracy: 0.8175 - val_loss: 0.5749
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject16
# Accuracy     : 0.8175
# Precision    : 0.8357
# Recall       : 0.8175
# F1 Score     : 0.7839
# Specificity  : 0.8367
# Saved model for Subject Subject16 to /kaggle/working/loso_model_subject_Subject16.h5
#
# --- Evaluating on Subject Subject17 ---
# Epoch 1/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.6252 - loss: 0.9472 - val_accuracy: 0.4892 - val_loss: 1.2120
# Epoch 2/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.6994 - loss: 0.7699 - val_accuracy: 0.5000 - val_loss: 1.1874
# Epoch 3/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 143s 149ms/step - accuracy: 0.7148 - loss: 0.7175 - val_accuracy: 0.5589 - val_loss: 1.1429
# Epoch 4/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7240 - loss: 0.6959 - val_accuracy: 0.5462 - val_loss: 1.0826
# Epoch 5/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 85s 150ms/step - accuracy: 0.7326 - loss: 0.6637 - val_accuracy: 0.5472 - val_loss: 1.1340
# Epoch 6/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7407 - loss: 0.6556 - val_accuracy: 0.5255 - val_loss: 1.1902
# Epoch 7/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7397 - loss: 0.6496 - val_accuracy: 0.5246 - val_loss: 1.1700
# Epoch 8/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7521 - loss: 0.6217 - val_accuracy: 0.4941 - val_loss: 1.1715
# Epoch 9/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7595 - loss: 0.5941 - val_accuracy: 0.5167 - val_loss: 1.1454
# Epoch 10/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7596 - loss: 0.5929 - val_accuracy: 0.5177 - val_loss: 1.1912
# Epoch 11/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 80s 143ms/step - accuracy: 0.7628 - loss: 0.5899 - val_accuracy: 0.5334 - val_loss: 1.1595
# Epoch 12/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7670 - loss: 0.5689 - val_accuracy: 0.5226 - val_loss: 1.2003
# Epoch 13/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 80s 143ms/step - accuracy: 0.7776 - loss: 0.5532 - val_accuracy: 0.5314 - val_loss: 1.1786
# Epoch 14/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7814 - loss: 0.5418 - val_accuracy: 0.4931 - val_loss: 1.1885
# Epoch 15/15
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7864 - loss: 0.5280 - val_accuracy: 0.5196 - val_loss: 1.2440
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
#
# Test Subject Subject17
# Accuracy     : 0.5196
# Precision    : 0.5572
# Recall       : 0.5196
# F1 Score     : 0.5263
# Specificity  : 0.7392
# Saved model for Subject Subject17 to /kaggle/working/loso_model_subject_Subject17.h5
#
# --- Evaluating on Subject Subject18 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 145ms/step - accuracy: 0.6219 - loss: 0.9603 - val_accuracy: 0.7118 - val_loss: 0.7325
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 146ms/step - accuracy: 0.6951 - loss: 0.7951 - val_accuracy: 0.7228 - val_loss: 0.7397
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7085 - loss: 0.7369 - val_accuracy: 0.7162 - val_loss: 0.7313
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7164 - loss: 0.7179 - val_accuracy: 0.6975 - val_loss: 0.7683
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7236 - loss: 0.6962 - val_accuracy: 0.7129 - val_loss: 0.7388
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7266 - loss: 0.6826 - val_accuracy: 0.7129 - val_loss: 0.7147
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.7311 - loss: 0.6589 - val_accuracy: 0.7206 - val_loss: 0.7046
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7372 - loss: 0.6494 - val_accuracy: 0.7173 - val_loss: 0.7196
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 147ms/step - accuracy: 0.7336 - loss: 0.6534 - val_accuracy: 0.7206 - val_loss: 0.7238
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 149ms/step - accuracy: 0.7427 - loss: 0.6285 - val_accuracy: 0.7283 - val_loss: 0.6738
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7557 - loss: 0.6081 - val_accuracy: 0.7283 - val_loss: 0.6843
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7622 - loss: 0.5938 - val_accuracy: 0.7602 - val_loss: 0.6039
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 147ms/step - accuracy: 0.7719 - loss: 0.5631 - val_accuracy: 0.7756 - val_loss: 0.5674
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7928 - loss: 0.5172 - val_accuracy: 0.8295 - val_loss: 0.4350
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.8181 - loss: 0.4615 - val_accuracy: 0.8273 - val_loss: 0.4363
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# Test Subject Subject18
# Accuracy     : 0.8273
# Precision    : 0.8291
# Recall       : 0.8273
# F1 Score     : 0.8162
# Specificity  : 0.8720
# Saved model for Subject Subject18 to /kaggle/working/loso_model_subject_Subject18.h5
#
# --- Evaluating on Subject Subject19 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 86s 146ms/step - accuracy: 0.6247 - loss: 0.9440 - val_accuracy: 0.6626 - val_loss: 0.8290
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7002 - loss: 0.7764 - val_accuracy: 0.6604 - val_loss: 0.8299
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7031 - loss: 0.7473 - val_accuracy: 0.6869 - val_loss: 0.7792
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7179 - loss: 0.7177 - val_accuracy: 0.7178 - val_loss: 0.7754
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7180 - loss: 0.7035 - val_accuracy: 0.7012 - val_loss: 0.8369
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7249 - loss: 0.6761 - val_accuracy: 0.7277 - val_loss: 0.7699
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7299 - loss: 0.6633 - val_accuracy: 0.7288 - val_loss: 0.7587
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 143ms/step - accuracy: 0.7388 - loss: 0.6444 - val_accuracy: 0.7211 - val_loss: 0.7716
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7417 - loss: 0.6279 - val_accuracy: 0.7354 - val_loss: 0.7598
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7498 - loss: 0.6097 - val_accuracy: 0.6913 - val_loss: 0.7732
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 149ms/step - accuracy: 0.7644 - loss: 0.5896 - val_accuracy: 0.7089 - val_loss: 0.7980
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 141s 148ms/step - accuracy: 0.7639 - loss: 0.5767 - val_accuracy: 0.7078 - val_loss: 0.7636
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7753 - loss: 0.5505 - val_accuracy: 0.7387 - val_loss: 0.6698
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 144s 149ms/step - accuracy: 0.8032 - loss: 0.4900 - val_accuracy: 0.7365 - val_loss: 0.6200
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.8331 - loss: 0.4206 - val_accuracy: 0.7740 - val_loss: 0.6247
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject19
# Accuracy     : 0.7740
# Precision    : 0.7918
# Recall       : 0.7740
# F1 Score     : 0.7395
# Specificity  : 0.8279
# Saved model for Subject Subject19 to /kaggle/working/loso_model_subject_Subject19.h5
#
# --- Evaluating on Subject Subject2 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 88s 150ms/step - accuracy: 0.6158 - loss: 0.9696 - val_accuracy: 0.7061 - val_loss: 0.7430
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.6949 - loss: 0.7910 - val_accuracy: 0.7533 - val_loss: 0.6929
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 144s 149ms/step - accuracy: 0.7070 - loss: 0.7404 - val_accuracy: 0.7511 - val_loss: 0.6638
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7169 - loss: 0.7150 - val_accuracy: 0.7368 - val_loss: 0.6572
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7234 - loss: 0.6893 - val_accuracy: 0.7445 - val_loss: 0.6901
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7243 - loss: 0.6808 - val_accuracy: 0.7357 - val_loss: 0.6690
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7320 - loss: 0.6723 - val_accuracy: 0.7368 - val_loss: 0.7442
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 149ms/step - accuracy: 0.7346 - loss: 0.6564 - val_accuracy: 0.7237 - val_loss: 0.6846
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7397 - loss: 0.6376 - val_accuracy: 0.7357 - val_loss: 0.7125
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7463 - loss: 0.6205 - val_accuracy: 0.7588 - val_loss: 0.6714
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 144ms/step - accuracy: 0.7552 - loss: 0.6130 - val_accuracy: 0.7456 - val_loss: 0.6589
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7555 - loss: 0.5963 - val_accuracy: 0.7434 - val_loss: 0.6652
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 148ms/step - accuracy: 0.7676 - loss: 0.5784 - val_accuracy: 0.7544 - val_loss: 0.6824
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7745 - loss: 0.5497 - val_accuracy: 0.7511 - val_loss: 0.6394
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 148ms/step - accuracy: 0.7842 - loss: 0.5369 - val_accuracy: 0.7555 - val_loss: 0.6306
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject2
# Accuracy     : 0.7555
# Precision    : 0.7423
# Recall       : 0.7555
# F1 Score     : 0.7251
# Specificity  : 0.8430
# Saved model for Subject Subject2 to /kaggle/working/loso_model_subject_Subject2.h5
#
# --- Evaluating on Subject Subject20 ---
# Epoch 1/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 87s 149ms/step - accuracy: 0.6174 - loss: 0.9680 - val_accuracy: 0.6464 - val_loss: 0.8204
# Epoch 2/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.6958 - loss: 0.7932 - val_accuracy: 0.6245 - val_loss: 0.8488
# Epoch 3/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 83s 145ms/step - accuracy: 0.7096 - loss: 0.7473 - val_accuracy: 0.5973 - val_loss: 0.8932
# Epoch 4/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 81s 144ms/step - accuracy: 0.7139 - loss: 0.7256 - val_accuracy: 0.6164 - val_loss: 0.8821
# Epoch 5/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7224 - loss: 0.7000 - val_accuracy: 0.6309 - val_loss: 0.8575
# Epoch 6/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 143s 149ms/step - accuracy: 0.7293 - loss: 0.6816 - val_accuracy: 0.6236 - val_loss: 0.9071
# Epoch 7/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 143s 151ms/step - accuracy: 0.7304 - loss: 0.6659 - val_accuracy: 0.6318 - val_loss: 0.8917
# Epoch 8/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 141s 150ms/step - accuracy: 0.7360 - loss: 0.6631 - val_accuracy: 0.6282 - val_loss: 0.8067
# Epoch 9/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 147ms/step - accuracy: 0.7370 - loss: 0.6491 - val_accuracy: 0.6591 - val_loss: 0.8018
# Epoch 10/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 83s 148ms/step - accuracy: 0.7387 - loss: 0.6410 - val_accuracy: 0.6609 - val_loss: 0.8240
# Epoch 11/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7467 - loss: 0.6212 - val_accuracy: 0.6027 - val_loss: 0.9568
# Epoch 12/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7506 - loss: 0.6130 - val_accuracy: 0.6355 - val_loss: 0.8118
# Epoch 13/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7499 - loss: 0.6195 - val_accuracy: 0.6291 - val_loss: 0.8945
# Epoch 14/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 84s 150ms/step - accuracy: 0.7636 - loss: 0.5863 - val_accuracy: 0.6209 - val_loss: 1.0031
# Epoch 15/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 82s 147ms/step - accuracy: 0.7686 - loss: 0.5705 - val_accuracy: 0.6273 - val_loss: 0.9071
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
#
# Test Subject Subject20
# Accuracy     : 0.6273
# Precision    : 0.6134
# Recall       : 0.6273
# F1 Score     : 0.6186
# Specificity  : 0.7959
# Saved model for Subject Subject20 to /kaggle/working/loso_model_subject_Subject20.h5
#
# --- Evaluating on Subject Subject3 ---
# Epoch 1/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 87s 148ms/step - accuracy: 0.6389 - loss: 0.9321 - val_accuracy: 0.6709 - val_loss: 0.8267
# Epoch 2/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.6941 - loss: 0.7955 - val_accuracy: 0.6729 - val_loss: 0.8070
# Epoch 3/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 145s 151ms/step - accuracy: 0.7106 - loss: 0.7524 - val_accuracy: 0.6640 - val_loss: 0.8941
# Epoch 4/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7261 - loss: 0.7049 - val_accuracy: 0.6759 - val_loss: 0.8145
# Epoch 5/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 144s 150ms/step - accuracy: 0.7274 - loss: 0.6828 - val_accuracy: 0.6611 - val_loss: 0.8232
# Epoch 6/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7254 - loss: 0.6802 - val_accuracy: 0.6670 - val_loss: 0.8113
# Epoch 7/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7322 - loss: 0.6681 - val_accuracy: 0.6522 - val_loss: 0.8752
# Epoch 8/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7381 - loss: 0.6511 - val_accuracy: 0.6690 - val_loss: 0.8063
# Epoch 9/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7485 - loss: 0.6244 - val_accuracy: 0.6650 - val_loss: 0.7898
# Epoch 10/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7511 - loss: 0.6149 - val_accuracy: 0.6719 - val_loss: 0.8449
# Epoch 11/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 148ms/step - accuracy: 0.7593 - loss: 0.5932 - val_accuracy: 0.6650 - val_loss: 0.7820
# Epoch 12/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 148ms/step - accuracy: 0.7610 - loss: 0.5844 - val_accuracy: 0.6591 - val_loss: 0.8623
# Epoch 13/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7834 - loss: 0.5436 - val_accuracy: 0.6601 - val_loss: 0.9037
# Epoch 14/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7990 - loss: 0.5025 - val_accuracy: 0.6502 - val_loss: 0.9757
# Epoch 15/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 144s 151ms/step - accuracy: 0.8233 - loss: 0.4457 - val_accuracy: 0.5889 - val_loss: 1.0113
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject3
# Accuracy     : 0.5889
# Precision    : 0.5562
# Recall       : 0.5889
# F1 Score     : 0.5616
# Specificity  : 0.6720
# Saved model for Subject Subject3 to /kaggle/working/loso_model_subject_Subject3.h5
#
# --- Evaluating on Subject Subject4 ---
# Epoch 1/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 87s 149ms/step - accuracy: 0.6233 - loss: 0.9440 - val_accuracy: 0.7310 - val_loss: 0.7251
# Epoch 2/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7032 - loss: 0.7809 - val_accuracy: 0.7280 - val_loss: 0.6903
# Epoch 3/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 87s 154ms/step - accuracy: 0.7036 - loss: 0.7470 - val_accuracy: 0.7140 - val_loss: 0.7556
# Epoch 4/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7121 - loss: 0.7168 - val_accuracy: 0.7310 - val_loss: 0.6861
# Epoch 5/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 144s 152ms/step - accuracy: 0.7249 - loss: 0.6922 - val_accuracy: 0.7330 - val_loss: 0.7119
# Epoch 6/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 142s 151ms/step - accuracy: 0.7297 - loss: 0.6717 - val_accuracy: 0.7310 - val_loss: 0.7695
# Epoch 7/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 148ms/step - accuracy: 0.7344 - loss: 0.6598 - val_accuracy: 0.7320 - val_loss: 0.8609
# Epoch 8/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7403 - loss: 0.6390 - val_accuracy: 0.7260 - val_loss: 0.8321
# Epoch 9/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7500 - loss: 0.6187 - val_accuracy: 0.7400 - val_loss: 0.7621
# Epoch 10/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7611 - loss: 0.5960 - val_accuracy: 0.7230 - val_loss: 0.8463
# Epoch 11/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 143s 150ms/step - accuracy: 0.7679 - loss: 0.5752 - val_accuracy: 0.7150 - val_loss: 0.8372
# Epoch 12/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7931 - loss: 0.5123 - val_accuracy: 0.7000 - val_loss: 0.8770
# Epoch 13/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.8353 - loss: 0.4288 - val_accuracy: 0.5910 - val_loss: 1.0657
# Epoch 14/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.8506 - loss: 0.3976 - val_accuracy: 0.5880 - val_loss: 1.0551
# Epoch 15/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.8660 - loss: 0.3589 - val_accuracy: 0.6200 - val_loss: 1.0682
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
#
# Test Subject Subject4
# Accuracy     : 0.6200
# Precision    : 0.5953
# Recall       : 0.6200
# F1 Score     : 0.5989
# Specificity  : 0.7395
# Saved model for Subject Subject4 to /kaggle/working/loso_model_subject_Subject4.h5
#
# --- Evaluating on Subject Subject5 ---
# Epoch 1/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 88s 150ms/step - accuracy: 0.6295 - loss: 0.9434 - val_accuracy: 0.7126 - val_loss: 0.8101
# Epoch 2/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.6937 - loss: 0.7953 - val_accuracy: 0.7075 - val_loss: 0.7568
# Epoch 3/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7080 - loss: 0.7519 - val_accuracy: 0.6893 - val_loss: 0.8025
# Epoch 4/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7133 - loss: 0.7256 - val_accuracy: 0.6741 - val_loss: 0.8067
# Epoch 5/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 82s 146ms/step - accuracy: 0.7136 - loss: 0.7172 - val_accuracy: 0.7126 - val_loss: 0.7212
# Epoch 6/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7222 - loss: 0.6991 - val_accuracy: 0.7126 - val_loss: 0.7198
# Epoch 7/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 85s 150ms/step - accuracy: 0.7326 - loss: 0.6800 - val_accuracy: 0.7156 - val_loss: 0.6924
# Epoch 8/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7392 - loss: 0.6519 - val_accuracy: 0.7095 - val_loss: 0.7189
# Epoch 9/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 142s 150ms/step - accuracy: 0.7436 - loss: 0.6396 - val_accuracy: 0.6711 - val_loss: 0.7383
# Epoch 10/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 142s 151ms/step - accuracy: 0.7435 - loss: 0.6307 - val_accuracy: 0.6640 - val_loss: 0.7646
# Epoch 11/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7531 - loss: 0.6118 - val_accuracy: 0.7095 - val_loss: 0.7050
# Epoch 12/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7527 - loss: 0.6091 - val_accuracy: 0.6630 - val_loss: 0.7757
# Epoch 13/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 150ms/step - accuracy: 0.7598 - loss: 0.5916 - val_accuracy: 0.7146 - val_loss: 0.6711
# Epoch 14/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7637 - loss: 0.5718 - val_accuracy: 0.6923 - val_loss: 0.7144
# Epoch 15/15
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7718 - loss: 0.5567 - val_accuracy: 0.6953 - val_loss: 0.6963
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
#
# Test Subject Subject5
# Accuracy     : 0.6953
# Precision    : 0.6993
# Recall       : 0.6953
# F1 Score     : 0.6970
# Specificity  : 0.8592
# Saved model for Subject Subject5 to /kaggle/working/loso_model_subject_Subject5.h5
#
# --- Evaluating on Subject Subject6 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 90s 154ms/step - accuracy: 0.6085 - loss: 0.9774 - val_accuracy: 0.6322 - val_loss: 0.9228
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.6880 - loss: 0.7970 - val_accuracy: 0.6289 - val_loss: 0.9137
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7072 - loss: 0.7410 - val_accuracy: 0.6311 - val_loss: 0.9384
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7239 - loss: 0.7064 - val_accuracy: 0.6267 - val_loss: 0.9542
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7216 - loss: 0.6955 - val_accuracy: 0.6300 - val_loss: 0.9149
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7347 - loss: 0.6655 - val_accuracy: 0.6167 - val_loss: 0.9328
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7419 - loss: 0.6463 - val_accuracy: 0.6388 - val_loss: 0.9146
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 86s 151ms/step - accuracy: 0.7437 - loss: 0.6382 - val_accuracy: 0.6520 - val_loss: 0.8600
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7408 - loss: 0.6465 - val_accuracy: 0.6278 - val_loss: 0.9595
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7492 - loss: 0.6202 - val_accuracy: 0.6256 - val_loss: 0.9547
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 145s 152ms/step - accuracy: 0.7501 - loss: 0.6096 - val_accuracy: 0.6410 - val_loss: 0.8965
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7620 - loss: 0.5841 - val_accuracy: 0.6244 - val_loss: 0.9150
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 149ms/step - accuracy: 0.7719 - loss: 0.5655 - val_accuracy: 0.6542 - val_loss: 0.8770
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7810 - loss: 0.5484 - val_accuracy: 0.6377 - val_loss: 0.8766
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7968 - loss: 0.5085 - val_accuracy: 0.6608 - val_loss: 0.7701
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject6
# Accuracy     : 0.6608
# Precision    : 0.7044
# Recall       : 0.6608
# F1 Score     : 0.6670
# Specificity  : 0.8393
# Saved model for Subject Subject6 to /kaggle/working/loso_model_subject_Subject6.h5
#
# --- Evaluating on Subject Subject7 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 88s 150ms/step - accuracy: 0.6053 - loss: 0.9949 - val_accuracy: 0.6858 - val_loss: 0.7847
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.6838 - loss: 0.8123 - val_accuracy: 0.7069 - val_loss: 0.7432
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.6999 - loss: 0.7641 - val_accuracy: 0.7113 - val_loss: 0.6938
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 141s 146ms/step - accuracy: 0.7114 - loss: 0.7256 - val_accuracy: 0.7279 - val_loss: 0.7369
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7157 - loss: 0.7062 - val_accuracy: 0.7312 - val_loss: 0.6977
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7225 - loss: 0.6752 - val_accuracy: 0.7334 - val_loss: 0.6541
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7295 - loss: 0.6682 - val_accuracy: 0.7500 - val_loss: 0.6830
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7315 - loss: 0.6570 - val_accuracy: 0.7113 - val_loss: 0.7729
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7285 - loss: 0.6539 - val_accuracy: 0.7301 - val_loss: 0.6810
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 141s 145ms/step - accuracy: 0.7303 - loss: 0.6505 - val_accuracy: 0.7478 - val_loss: 0.6740
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7492 - loss: 0.6148 - val_accuracy: 0.7434 - val_loss: 0.6873
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 82s 145ms/step - accuracy: 0.7494 - loss: 0.6068 - val_accuracy: 0.7577 - val_loss: 0.6688
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7534 - loss: 0.5947 - val_accuracy: 0.7168 - val_loss: 0.7247
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 79s 140ms/step - accuracy: 0.7605 - loss: 0.5850 - val_accuracy: 0.7423 - val_loss: 0.6947
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7593 - loss: 0.5774 - val_accuracy: 0.7577 - val_loss: 0.6444
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Test Subject Subject7
# Accuracy     : 0.7577
# Precision    : 0.7730
# Recall       : 0.7577
# F1 Score     : 0.7618
# Specificity  : 0.9148
# Saved model for Subject Subject7 to /kaggle/working/loso_model_subject_Subject7.h5
#
# --- Evaluating on Subject Subject8 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 144ms/step - accuracy: 0.6183 - loss: 0.9743 - val_accuracy: 0.6568 - val_loss: 0.8597
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.6788 - loss: 0.8170 - val_accuracy: 0.7140 - val_loss: 0.7220
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.6954 - loss: 0.7706 - val_accuracy: 0.6788 - val_loss: 0.7584
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7100 - loss: 0.7406 - val_accuracy: 0.6733 - val_loss: 0.7530
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 148ms/step - accuracy: 0.7196 - loss: 0.7088 - val_accuracy: 0.7096 - val_loss: 0.6749
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7194 - loss: 0.6993 - val_accuracy: 0.6876 - val_loss: 0.7437
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 141s 147ms/step - accuracy: 0.7307 - loss: 0.6781 - val_accuracy: 0.7261 - val_loss: 0.6306
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7331 - loss: 0.6644 - val_accuracy: 0.7305 - val_loss: 0.6401
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7344 - loss: 0.6535 - val_accuracy: 0.7426 - val_loss: 0.5967
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7401 - loss: 0.6383 - val_accuracy: 0.6865 - val_loss: 0.6624
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 149ms/step - accuracy: 0.7410 - loss: 0.6316 - val_accuracy: 0.7129 - val_loss: 0.6657
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 149ms/step - accuracy: 0.7463 - loss: 0.6208 - val_accuracy: 0.7118 - val_loss: 0.6276
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7613 - loss: 0.6021 - val_accuracy: 0.7195 - val_loss: 0.5894
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 85s 149ms/step - accuracy: 0.7601 - loss: 0.5861 - val_accuracy: 0.7492 - val_loss: 0.6090
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7572 - loss: 0.5872 - val_accuracy: 0.7118 - val_loss: 0.6582
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
#
# Test Subject Subject8
# Accuracy     : 0.7118
# Precision    : 0.7113
# Recall       : 0.7118
# F1 Score     : 0.6636
# Specificity  : 0.7208
# Saved model for Subject Subject8 to /kaggle/working/loso_model_subject_Subject8.h5
#
# --- Evaluating on Subject Subject9 ---
# Epoch 1/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 87s 148ms/step - accuracy: 0.6163 - loss: 0.9728 - val_accuracy: 0.7269 - val_loss: 0.6798
# Epoch 2/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.6926 - loss: 0.7927 - val_accuracy: 0.7357 - val_loss: 0.6574
# Epoch 3/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 80s 141ms/step - accuracy: 0.7002 - loss: 0.7516 - val_accuracy: 0.7434 - val_loss: 0.6265
# Epoch 4/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7163 - loss: 0.7129 - val_accuracy: 0.7698 - val_loss: 0.6683
# Epoch 5/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 144s 149ms/step - accuracy: 0.7177 - loss: 0.7098 - val_accuracy: 0.7698 - val_loss: 0.5889
# Epoch 6/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 146ms/step - accuracy: 0.7254 - loss: 0.6849 - val_accuracy: 0.7489 - val_loss: 0.5791
# Epoch 7/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 143ms/step - accuracy: 0.7326 - loss: 0.6765 - val_accuracy: 0.7643 - val_loss: 0.5582
# Epoch 8/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 148ms/step - accuracy: 0.7381 - loss: 0.6503 - val_accuracy: 0.7632 - val_loss: 0.5885
# Epoch 9/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 81s 142ms/step - accuracy: 0.7387 - loss: 0.6482 - val_accuracy: 0.7731 - val_loss: 0.5506
# Epoch 10/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7427 - loss: 0.6325 - val_accuracy: 0.7786 - val_loss: 0.5033
# Epoch 11/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 142s 148ms/step - accuracy: 0.7480 - loss: 0.6223 - val_accuracy: 0.7577 - val_loss: 0.5678
# Epoch 12/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.7516 - loss: 0.6118 - val_accuracy: 0.7819 - val_loss: 0.5052
# Epoch 13/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 143s 148ms/step - accuracy: 0.7549 - loss: 0.5934 - val_accuracy: 0.7511 - val_loss: 0.5674
# Epoch 14/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 79s 139ms/step - accuracy: 0.7621 - loss: 0.5839 - val_accuracy: 0.7941 - val_loss: 0.4723
# Epoch 15/15
# 568/568 ━━━━━━━━━━━━━━━━━━━━ 84s 147ms/step - accuracy: 0.7665 - loss: 0.5683 - val_accuracy: 0.7753 - val_loss: 0.5079
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
#
# Test Subject Subject9
# Accuracy     : 0.7753
# Precision    : 0.7570
# Recall       : 0.7753
# F1 Score     : 0.7503
# Specificity  : 0.8661
# Saved model for Subject Subject9 to /kaggle/working/loso_model_subject_Subject9.h5
#
# === LOSO Evaluation Summary ===
# Average Accuracy    : 0.7260535554257432
# Average Precision   : 0.7247487874887337
# Average Recall      : 0.7260535554257432
# Average F1 Score    : 0.7095183107669737
# Average Specificity : 0.821615675633972

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cleaned/cleaned_dataset.csv

# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 43.9 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import pandas as pd
from pyts.image import MarkovTransitionField
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import warnings
from collections import Counter
import gc
from tensorflow.keras import backend as K
from pyts.image import GramianAngularField

warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/kaggle/input/cleaned/cleaned_dataset.csv')  # Replace with your path
df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.sort_values(['SubjectID', 'DateTime'])

# Preprocess features
feature_cols = ['AccX', 'AccY', 'AccZ', 'Temp', 'EDA', 'HeartRate', 'SpO2']
target_col = 'Label'

scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

def create_windows(df, feature_cols, target_col, window_size=100, step=20):
    X = []
    y = []
    for subject_id, subject_df in df.groupby('SubjectID'):
        subject_data = subject_df.reset_index(drop=True)
        features = subject_data[feature_cols].values
        labels = subject_data[target_col].values
        for start in range(0, len(features) - window_size, step):
            end = start + window_size
            window_x = features[start:end]
            window_y = labels[start:end]
            label = Counter(window_y).most_common(1)[0][0]
            X.append(window_x)
            y.append(label)
    return np.array(X), np.array(y)

X, y = create_windows(df, feature_cols, target_col)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Convert time-series to images using MTF
def time_series_to_image_gaf(sample, image_size=64, method='summation'):
    gaf = GramianAngularField(image_size=image_size, method=method)
    img_list = []
    for i in range(sample.shape[1]):
        ts = sample[:, i]
        img = gaf.fit_transform(ts.reshape(1, -1))[0]
        img_list.append(img)
    img = np.stack(img_list, axis=-1)
    return img

image_data = np.array([time_series_to_image_gaf(seq) for seq in X])


# CNN model
def build_image_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Evaluation
def evaluate_model(model, X_test, y_test, label_encoder, title="Model"):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    specificity_per_class = []
    for i in range(len(cm)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(np.delete(cm, i, axis=0)[:, i])
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        specificity_per_class.append(specificity)
    weighted_specificity = np.average(specificity_per_class, weights=np.bincount(y_true_classes))

    print(f"\n{title}")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"F1 Score     : {f1:.4f}")
    print(f"Specificity  : {weighted_specificity:.4f}")

    return accuracy, precision, recall, f1, weighted_specificity

# Intra-Subject Classification: Ensure data consistency for splitting
results_subjectwise = {}
for subject_id, subject_df in df.groupby('SubjectID'):
    X_subject, y_subject = create_windows(subject_df, feature_cols, target_col)
    
    # Convert time-series data to images for subject-wise classification
    image_data_subject = np.array([time_series_to_image_gaf(seq) for seq in X_subject])
    
    # Ensure labels and features have the same length for splitting
    y_subject_encoded = le.transform(y_subject)
    
    X_train_subj, X_test_subj, y_train_subj, y_test_subj = train_test_split(
        image_data_subject, to_categorical(y_subject_encoded), test_size=0.2, stratify=y_subject_encoded, random_state=42
    )
    
    img_model_subj = build_image_model(X_train_subj.shape[1:], y_cat.shape[1])
    img_model_subj.fit(X_train_subj, y_train_subj, validation_data=(X_test_subj, y_test_subj),
                       epochs=20, batch_size=32)
    
    acc, precision, recall, f1, specificity = evaluate_model(img_model_subj, X_test_subj, y_test_subj, le, title=f"Subject {subject_id}")
    results_subjectwise[subject_id] = {'Accuracy': acc, 'Precision': precision, 'Recall': recall, 'F1': f1, 'Specificity': specificity}
# === Summary ===

print("\n=== Summary Metrics ===")

# Average Per-Subject Metrics
print("\n=== Per-Subject Metrics ===")
print("Average Per-Subject Accuracy:", np.mean([result['Accuracy'] for result in results_subjectwise.values()]))
print("Average Per-Subject Precision:", np.mean([result['Precision'] for result in results_subjectwise.values()]))
print("Average Per-Subject Recall:", np.mean([result['Recall'] for result in results_subjectwise.values()]))
print("Average Per-Subject F1 Score:", np.mean([result['F1'] for result in results_subjectwise.values()]))
print("Average Per-Subject Specificity:", np.mean([result['Specificity'] for result in results_subjectwise.values()]))

# Save results to a text file
with open("/kaggle/working/intra_subject_results_summary.txt", "w") as f:
    f.write("=== Per-Subject Metrics ===\n")
    for subject_id, metrics in results_subjectwise.items():
        f.write(f"\nSubject {subject_id}:\n")
        for metric, value in metrics.items():
            f.write(f"{metric}: {value:.4f}\n")
    
    f.write("\n=== Average Per-Subject Metrics ===\n")
    f.write(f"Average Per-Subject Accuracy: {np.mean([result['Accuracy'] for result in results_subjectwise.values()]):.4f}\n")
    f.write(f"Average Per-Subject Precision: {np.mean([result['Precision'] for result in results_subjectwise.values()]):.4f}\n")
    f.write(f"Average Per-Subject Recall: {np.mean([result['Recall'] for result in results_subjectwise.values()]):.4f}\n")
    f.write(f"Average Per-Subject F1 Score: {np.mean([result['F1'] for result in results_subjectwise.values()]):.4f}\n")
    f.write(f"Average Per-Subject Specificity: {np.mean([result['Specificity'] for result in results_subjectwise.values()]):.4f}\n")

print("\nResults saved to 'intra_subject_results_summary.txt'")
# Out:
# 2025-04-14 03:42:18.488333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744602138.710492      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744602138.778928      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-14 03:43:53.778253: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 210ms/step - accuracy: 0.4905 - loss: 1.1860 - val_accuracy: 0.5888 - val_loss: 0.9108
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.5751 - loss: 0.9346 - val_accuracy: 0.6244 - val_loss: 0.8132
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.6535 - loss: 0.8433 - val_accuracy: 0.6599 - val_loss: 0.7798
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6546 - loss: 0.8117 - val_accuracy: 0.6548 - val_loss: 0.7773
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.6635 - loss: 0.7936 - val_accuracy: 0.6193 - val_loss: 0.7809
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6728 - loss: 0.7212 - val_accuracy: 0.6599 - val_loss: 0.7388
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7296 - loss: 0.6571 - val_accuracy: 0.6853 - val_loss: 0.7318
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7269 - loss: 0.6775 - val_accuracy: 0.6548 - val_loss: 0.7081
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7597 - loss: 0.6317 - val_accuracy: 0.6802 - val_loss: 0.7078
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7521 - loss: 0.6082 - val_accuracy: 0.6751 - val_loss: 0.6882
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7550 - loss: 0.6344 - val_accuracy: 0.7005 - val_loss: 0.6955
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7813 - loss: 0.5595 - val_accuracy: 0.6802 - val_loss: 0.6795
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.7969 - loss: 0.5205 - val_accuracy: 0.6904 - val_loss: 0.6920
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7937 - loss: 0.5133 - val_accuracy: 0.7107 - val_loss: 0.6965
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8240 - loss: 0.4875 - val_accuracy: 0.6904 - val_loss: 0.6775
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8234 - loss: 0.4692 - val_accuracy: 0.7157 - val_loss: 0.6617
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8183 - loss: 0.4602 - val_accuracy: 0.6802 - val_loss: 0.7305
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.8293 - loss: 0.4175 - val_accuracy: 0.7056 - val_loss: 0.6497
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8277 - loss: 0.4488 - val_accuracy: 0.6954 - val_loss: 0.6647
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8681 - loss: 0.3788 - val_accuracy: 0.7360 - val_loss: 0.6747
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
#
# Subject Subject1
# Accuracy     : 0.7360
# Precision    : 0.7147
# Recall       : 0.7360
# F1 Score     : 0.7200
# Specificity  : 0.8463
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.4736 - loss: 1.1935 - val_accuracy: 0.5879 - val_loss: 0.8951
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.5926 - loss: 0.9040 - val_accuracy: 0.6593 - val_loss: 0.7719
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6450 - loss: 0.8055 - val_accuracy: 0.6593 - val_loss: 0.7440
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6704 - loss: 0.7713 - val_accuracy: 0.6703 - val_loss: 0.7174
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6872 - loss: 0.7338 - val_accuracy: 0.7143 - val_loss: 0.6965
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6840 - loss: 0.7574 - val_accuracy: 0.7308 - val_loss: 0.6803
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.7403 - loss: 0.6592 - val_accuracy: 0.6758 - val_loss: 0.6847
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7387 - loss: 0.6155 - val_accuracy: 0.7527 - val_loss: 0.6554
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7705 - loss: 0.6046 - val_accuracy: 0.7253 - val_loss: 0.6649
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7724 - loss: 0.5983 - val_accuracy: 0.7473 - val_loss: 0.6413
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.7519 - loss: 0.5939 - val_accuracy: 0.7143 - val_loss: 0.6399
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7848 - loss: 0.5402 - val_accuracy: 0.7088 - val_loss: 0.6251
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7448 - loss: 0.5773 - val_accuracy: 0.7198 - val_loss: 0.6226
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8033 - loss: 0.5315 - val_accuracy: 0.7253 - val_loss: 0.6454
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7908 - loss: 0.5208 - val_accuracy: 0.7253 - val_loss: 0.6304
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8382 - loss: 0.4696 - val_accuracy: 0.7308 - val_loss: 0.6170
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8140 - loss: 0.4649 - val_accuracy: 0.7418 - val_loss: 0.6035
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8595 - loss: 0.4203 - val_accuracy: 0.7198 - val_loss: 0.6306
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8367 - loss: 0.4327 - val_accuracy: 0.7308 - val_loss: 0.6120
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8625 - loss: 0.3797 - val_accuracy: 0.7253 - val_loss: 0.6114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Subject Subject10
# Accuracy     : 0.7253
# Precision    : 0.7268
# Recall       : 0.7253
# F1 Score     : 0.7242
# Specificity  : 0.8980
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 167ms/step - accuracy: 0.4448 - loss: 1.2598 - val_accuracy: 0.4956 - val_loss: 1.0927
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.5077 - loss: 1.0710 - val_accuracy: 0.5570 - val_loss: 1.0094
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.5546 - loss: 0.9985 - val_accuracy: 0.5482 - val_loss: 0.9706
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5549 - loss: 0.9378 - val_accuracy: 0.5482 - val_loss: 0.9133
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.6133 - loss: 0.8660 - val_accuracy: 0.5965 - val_loss: 0.8756
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.6663 - loss: 0.8009 - val_accuracy: 0.6272 - val_loss: 0.8352
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.6541 - loss: 0.7452 - val_accuracy: 0.6140 - val_loss: 0.8212
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6512 - loss: 0.7641 - val_accuracy: 0.6623 - val_loss: 0.7756
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.7319 - loss: 0.6871 - val_accuracy: 0.6272 - val_loss: 0.7833
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.6925 - loss: 0.6912 - val_accuracy: 0.6754 - val_loss: 0.7185
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7418 - loss: 0.6327 - val_accuracy: 0.6447 - val_loss: 0.7330
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.7338 - loss: 0.6549 - val_accuracy: 0.6535 - val_loss: 0.7347
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.7455 - loss: 0.6174 - val_accuracy: 0.6535 - val_loss: 0.7354
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.7601 - loss: 0.5917 - val_accuracy: 0.6798 - val_loss: 0.6948
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7917 - loss: 0.5250 - val_accuracy: 0.6798 - val_loss: 0.7222
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8094 - loss: 0.4934 - val_accuracy: 0.6447 - val_loss: 0.7431
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8331 - loss: 0.4607 - val_accuracy: 0.6623 - val_loss: 0.6927
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8118 - loss: 0.4710 - val_accuracy: 0.6886 - val_loss: 0.7181
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.8193 - loss: 0.4501 - val_accuracy: 0.6930 - val_loss: 0.6770
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8600 - loss: 0.3936 - val_accuracy: 0.6930 - val_loss: 0.7175
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Subject Subject11
# Accuracy     : 0.6930
# Precision    : 0.6902
# Recall       : 0.6930
# F1 Score     : 0.6723
# Specificity  : 0.7698
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - accuracy: 0.5092 - loss: 1.2449 - val_accuracy: 0.5405 - val_loss: 1.0059
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.5814 - loss: 0.9801 - val_accuracy: 0.6432 - val_loss: 0.9431
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.6360 - loss: 0.9118 - val_accuracy: 0.6216 - val_loss: 0.9230
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.6135 - loss: 0.9316 - val_accuracy: 0.6324 - val_loss: 0.9066
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6415 - loss: 0.8394 - val_accuracy: 0.6541 - val_loss: 0.8639
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.6605 - loss: 0.8348 - val_accuracy: 0.6378 - val_loss: 0.8491
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.6862 - loss: 0.8062 - val_accuracy: 0.6270 - val_loss: 0.8638
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6851 - loss: 0.7746 - val_accuracy: 0.6595 - val_loss: 0.8430
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7008 - loss: 0.7503 - val_accuracy: 0.6595 - val_loss: 0.8549
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.6730 - loss: 0.7423 - val_accuracy: 0.6541 - val_loss: 0.8032
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.7254 - loss: 0.7143 - val_accuracy: 0.6541 - val_loss: 0.7995
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.7410 - loss: 0.6836 - val_accuracy: 0.6703 - val_loss: 0.7981
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.7554 - loss: 0.6288 - val_accuracy: 0.6865 - val_loss: 0.7742
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7701 - loss: 0.6099 - val_accuracy: 0.6703 - val_loss: 0.7763
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7919 - loss: 0.5510 - val_accuracy: 0.6919 - val_loss: 0.7699
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7761 - loss: 0.5641 - val_accuracy: 0.7027 - val_loss: 0.7316
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.7819 - loss: 0.5440 - val_accuracy: 0.6757 - val_loss: 0.7368
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8180 - loss: 0.5103 - val_accuracy: 0.6703 - val_loss: 0.8150
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7803 - loss: 0.5380 - val_accuracy: 0.7135 - val_loss: 0.7280
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8036 - loss: 0.4864 - val_accuracy: 0.7081 - val_loss: 0.7760
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject12
# Accuracy     : 0.7081
# Precision    : 0.7074
# Recall       : 0.7081
# F1 Score     : 0.7022
# Specificity  : 0.8322
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.4278 - loss: 1.2413 - val_accuracy: 0.5769 - val_loss: 0.9900
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.5866 - loss: 0.9361 - val_accuracy: 0.6044 - val_loss: 0.9331
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.6130 - loss: 0.9015 - val_accuracy: 0.6099 - val_loss: 0.9017
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6553 - loss: 0.8260 - val_accuracy: 0.6209 - val_loss: 0.8620
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6517 - loss: 0.7800 - val_accuracy: 0.6319 - val_loss: 0.8441
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6867 - loss: 0.7742 - val_accuracy: 0.6264 - val_loss: 0.8242
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7149 - loss: 0.6899 - val_accuracy: 0.6758 - val_loss: 0.8244
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7499 - loss: 0.6582 - val_accuracy: 0.6758 - val_loss: 0.8012
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7253 - loss: 0.6566 - val_accuracy: 0.6813 - val_loss: 0.8009
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7792 - loss: 0.5827 - val_accuracy: 0.6703 - val_loss: 0.8036
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.7827 - loss: 0.5478 - val_accuracy: 0.6648 - val_loss: 0.7959
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7476 - loss: 0.5797 - val_accuracy: 0.6868 - val_loss: 0.7753
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7920 - loss: 0.5475 - val_accuracy: 0.6593 - val_loss: 0.7983
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7854 - loss: 0.5032 - val_accuracy: 0.6923 - val_loss: 0.7688
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8307 - loss: 0.4619 - val_accuracy: 0.6868 - val_loss: 0.7619
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8243 - loss: 0.4355 - val_accuracy: 0.7088 - val_loss: 0.7894
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8501 - loss: 0.4354 - val_accuracy: 0.6648 - val_loss: 0.7914
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8245 - loss: 0.4460 - val_accuracy: 0.6813 - val_loss: 0.7628
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.8468 - loss: 0.4043 - val_accuracy: 0.7033 - val_loss: 0.7598
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8780 - loss: 0.3849 - val_accuracy: 0.6868 - val_loss: 0.7657
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Subject Subject13
# Accuracy     : 0.6868
# Precision    : 0.6915
# Recall       : 0.6868
# F1 Score     : 0.6776
# Specificity  : 0.8832
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - accuracy: 0.5380 - loss: 1.1394 - val_accuracy: 0.5824 - val_loss: 0.9449
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6038 - loss: 0.9062 - val_accuracy: 0.6538 - val_loss: 0.8306
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7011 - loss: 0.7862 - val_accuracy: 0.6978 - val_loss: 0.7874
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6953 - loss: 0.7421 - val_accuracy: 0.6758 - val_loss: 0.7862
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6878 - loss: 0.7285 - val_accuracy: 0.7308 - val_loss: 0.7479
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7171 - loss: 0.6903 - val_accuracy: 0.7033 - val_loss: 0.7495
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7437 - loss: 0.6304 - val_accuracy: 0.7253 - val_loss: 0.7009
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7563 - loss: 0.5930 - val_accuracy: 0.7363 - val_loss: 0.6909
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7327 - loss: 0.5955 - val_accuracy: 0.7308 - val_loss: 0.6871
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7575 - loss: 0.5706 - val_accuracy: 0.7088 - val_loss: 0.6981
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7568 - loss: 0.5852 - val_accuracy: 0.7143 - val_loss: 0.7079
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7710 - loss: 0.5600 - val_accuracy: 0.7418 - val_loss: 0.6718
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.7896 - loss: 0.5410 - val_accuracy: 0.7418 - val_loss: 0.6645
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.8059 - loss: 0.4891 - val_accuracy: 0.7692 - val_loss: 0.6515
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8048 - loss: 0.4515 - val_accuracy: 0.7582 - val_loss: 0.6552
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8393 - loss: 0.4342 - val_accuracy: 0.7582 - val_loss: 0.6577
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8433 - loss: 0.4222 - val_accuracy: 0.7088 - val_loss: 0.7135
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8102 - loss: 0.4371 - val_accuracy: 0.7582 - val_loss: 0.6510
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8445 - loss: 0.4095 - val_accuracy: 0.7692 - val_loss: 0.6520
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8685 - loss: 0.3694 - val_accuracy: 0.7473 - val_loss: 0.6433
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Subject Subject14
# Accuracy     : 0.7473
# Precision    : 0.7464
# Recall       : 0.7473
# F1 Score     : 0.7418
# Specificity  : 0.8710
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.4473 - loss: 1.2320 - val_accuracy: 0.6133 - val_loss: 0.9281
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.5610 - loss: 0.9945 - val_accuracy: 0.6740 - val_loss: 0.8465
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.6390 - loss: 0.8905 - val_accuracy: 0.7072 - val_loss: 0.7986
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6596 - loss: 0.8483 - val_accuracy: 0.6796 - val_loss: 0.8078
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6481 - loss: 0.8087 - val_accuracy: 0.7238 - val_loss: 0.7465
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6737 - loss: 0.7912 - val_accuracy: 0.7348 - val_loss: 0.7354
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.6734 - loss: 0.7616 - val_accuracy: 0.7348 - val_loss: 0.7420
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7165 - loss: 0.6851 - val_accuracy: 0.7680 - val_loss: 0.7001
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7518 - loss: 0.6335 - val_accuracy: 0.7569 - val_loss: 0.7013
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7595 - loss: 0.6354 - val_accuracy: 0.7348 - val_loss: 0.6963
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7785 - loss: 0.5902 - val_accuracy: 0.7459 - val_loss: 0.6930
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7820 - loss: 0.6160 - val_accuracy: 0.7569 - val_loss: 0.6986
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7711 - loss: 0.5868 - val_accuracy: 0.7514 - val_loss: 0.6714
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7806 - loss: 0.5358 - val_accuracy: 0.7624 - val_loss: 0.6699
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8248 - loss: 0.4901 - val_accuracy: 0.7182 - val_loss: 0.6697
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.7881 - loss: 0.5231 - val_accuracy: 0.7348 - val_loss: 0.6558
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7876 - loss: 0.5275 - val_accuracy: 0.7403 - val_loss: 0.6641
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8152 - loss: 0.4697 - val_accuracy: 0.7293 - val_loss: 0.6424
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8296 - loss: 0.4808 - val_accuracy: 0.7735 - val_loss: 0.6384
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8502 - loss: 0.4300 - val_accuracy: 0.7624 - val_loss: 0.6449
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Subject Subject15
# Accuracy     : 0.7624
# Precision    : 0.7733
# Recall       : 0.7624
# F1 Score     : 0.7435
# Specificity  : 0.8803
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - accuracy: 0.4795 - loss: 1.1260 - val_accuracy: 0.6284 - val_loss: 0.9535
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.5883 - loss: 0.9036 - val_accuracy: 0.6393 - val_loss: 0.8955
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6548 - loss: 0.7980 - val_accuracy: 0.6230 - val_loss: 0.8649
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7231 - loss: 0.6983 - val_accuracy: 0.6284 - val_loss: 0.8488
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.6814 - loss: 0.6955 - val_accuracy: 0.6066 - val_loss: 0.8218
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7286 - loss: 0.6394 - val_accuracy: 0.6612 - val_loss: 0.8264
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7351 - loss: 0.6538 - val_accuracy: 0.6503 - val_loss: 0.8215
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.7404 - loss: 0.5879 - val_accuracy: 0.6557 - val_loss: 0.8076
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7496 - loss: 0.6150 - val_accuracy: 0.6557 - val_loss: 0.7908
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7676 - loss: 0.5658 - val_accuracy: 0.6284 - val_loss: 0.7908
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7946 - loss: 0.5555 - val_accuracy: 0.6339 - val_loss: 0.7835
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7792 - loss: 0.5425 - val_accuracy: 0.6503 - val_loss: 0.7741
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8125 - loss: 0.5097 - val_accuracy: 0.6885 - val_loss: 0.8017
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.7861 - loss: 0.5037 - val_accuracy: 0.6667 - val_loss: 0.7820
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7991 - loss: 0.4880 - val_accuracy: 0.6940 - val_loss: 0.7607
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8230 - loss: 0.4447 - val_accuracy: 0.6667 - val_loss: 0.8004
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.7991 - loss: 0.4806 - val_accuracy: 0.6667 - val_loss: 0.7816
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8430 - loss: 0.4114 - val_accuracy: 0.6393 - val_loss: 0.7974
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.8452 - loss: 0.4180 - val_accuracy: 0.6721 - val_loss: 0.8167
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8732 - loss: 0.3624 - val_accuracy: 0.6940 - val_loss: 0.7805
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#
# Subject Subject16
# Accuracy     : 0.6940
# Precision    : 0.6896
# Recall       : 0.6940
# F1 Score     : 0.6891
# Specificity  : 0.8334
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 179ms/step - accuracy: 0.4403 - loss: 1.2779 - val_accuracy: 0.5931 - val_loss: 1.0654
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.5823 - loss: 1.0781 - val_accuracy: 0.5980 - val_loss: 0.9877
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.5979 - loss: 0.9867 - val_accuracy: 0.6029 - val_loss: 0.9535
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.5856 - loss: 0.9973 - val_accuracy: 0.5931 - val_loss: 0.9416
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.5978 - loss: 0.9611 - val_accuracy: 0.5882 - val_loss: 0.9560
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.6059 - loss: 0.9571 - val_accuracy: 0.5980 - val_loss: 0.9134
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.6300 - loss: 0.8750 - val_accuracy: 0.5980 - val_loss: 0.8969
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6919 - loss: 0.8241 - val_accuracy: 0.6422 - val_loss: 0.8744
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6938 - loss: 0.7570 - val_accuracy: 0.6373 - val_loss: 0.8714
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6863 - loss: 0.7609 - val_accuracy: 0.6667 - val_loss: 0.8510
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7189 - loss: 0.7275 - val_accuracy: 0.6618 - val_loss: 0.8402
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.7020 - loss: 0.7060 - val_accuracy: 0.6569 - val_loss: 0.8409
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7368 - loss: 0.6702 - val_accuracy: 0.6029 - val_loss: 0.8492
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7478 - loss: 0.6555 - val_accuracy: 0.6569 - val_loss: 0.8651
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7571 - loss: 0.6194 - val_accuracy: 0.6569 - val_loss: 0.8444
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7407 - loss: 0.6436 - val_accuracy: 0.6520 - val_loss: 0.8321
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7752 - loss: 0.6061 - val_accuracy: 0.6618 - val_loss: 0.8615
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7466 - loss: 0.6080 - val_accuracy: 0.6618 - val_loss: 0.8097
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.7656 - loss: 0.5512 - val_accuracy: 0.6520 - val_loss: 0.8828
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7989 - loss: 0.5354 - val_accuracy: 0.6618 - val_loss: 0.8272
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Subject Subject17
# Accuracy     : 0.6618
# Precision    : 0.6459
# Recall       : 0.6618
# F1 Score     : 0.6414
# Specificity  : 0.7942
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 190ms/step - accuracy: 0.4575 - loss: 1.1771 - val_accuracy: 0.5385 - val_loss: 1.0111
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.5786 - loss: 0.9319 - val_accuracy: 0.6044 - val_loss: 0.9103
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6243 - loss: 0.8376 - val_accuracy: 0.7033 - val_loss: 0.8531
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6293 - loss: 0.8105 - val_accuracy: 0.6758 - val_loss: 0.8541
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.7366 - loss: 0.6799 - val_accuracy: 0.6923 - val_loss: 0.8482
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7351 - loss: 0.6502 - val_accuracy: 0.7088 - val_loss: 0.8353
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7300 - loss: 0.6541 - val_accuracy: 0.7088 - val_loss: 0.7971
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7352 - loss: 0.6393 - val_accuracy: 0.6923 - val_loss: 0.8266
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7592 - loss: 0.5947 - val_accuracy: 0.6813 - val_loss: 0.7941
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7671 - loss: 0.5823 - val_accuracy: 0.6923 - val_loss: 0.7765
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7625 - loss: 0.5489 - val_accuracy: 0.7033 - val_loss: 0.7800
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7698 - loss: 0.5696 - val_accuracy: 0.6923 - val_loss: 0.7715
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.7856 - loss: 0.4848 - val_accuracy: 0.7143 - val_loss: 0.7939
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8149 - loss: 0.4607 - val_accuracy: 0.6813 - val_loss: 0.7664
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8299 - loss: 0.4310 - val_accuracy: 0.7253 - val_loss: 0.7366
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8210 - loss: 0.4561 - val_accuracy: 0.7143 - val_loss: 0.7515
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8541 - loss: 0.3874 - val_accuracy: 0.7418 - val_loss: 0.7780
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8519 - loss: 0.3703 - val_accuracy: 0.7308 - val_loss: 0.7588
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8606 - loss: 0.3920 - val_accuracy: 0.7473 - val_loss: 0.7272
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8887 - loss: 0.3260 - val_accuracy: 0.7363 - val_loss: 0.7361
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Subject Subject18
# Accuracy     : 0.7363
# Precision    : 0.7405
# Recall       : 0.7363
# F1 Score     : 0.7263
# Specificity  : 0.8657
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - accuracy: 0.4917 - loss: 1.2063 - val_accuracy: 0.5275 - val_loss: 0.9967
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.5495 - loss: 1.0154 - val_accuracy: 0.5549 - val_loss: 0.9179
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.6188 - loss: 0.8606 - val_accuracy: 0.5879 - val_loss: 0.8913
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6441 - loss: 0.8530 - val_accuracy: 0.6209 - val_loss: 0.8327
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6552 - loss: 0.7947 - val_accuracy: 0.6429 - val_loss: 0.8107
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6600 - loss: 0.8205 - val_accuracy: 0.6593 - val_loss: 0.8166
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.6797 - loss: 0.7791 - val_accuracy: 0.6429 - val_loss: 0.8048
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.7092 - loss: 0.7252 - val_accuracy: 0.6484 - val_loss: 0.8029
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7103 - loss: 0.6887 - val_accuracy: 0.6813 - val_loss: 0.7697
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7233 - loss: 0.7254 - val_accuracy: 0.6374 - val_loss: 0.8348
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6611 - loss: 0.7648 - val_accuracy: 0.6923 - val_loss: 0.7670
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7416 - loss: 0.6750 - val_accuracy: 0.6538 - val_loss: 0.7914
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7547 - loss: 0.6568 - val_accuracy: 0.6264 - val_loss: 0.7944
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7589 - loss: 0.6039 - val_accuracy: 0.6978 - val_loss: 0.7331
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7834 - loss: 0.5661 - val_accuracy: 0.6978 - val_loss: 0.7276
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.7522 - loss: 0.6132 - val_accuracy: 0.7033 - val_loss: 0.7205
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7984 - loss: 0.5368 - val_accuracy: 0.6758 - val_loss: 0.7231
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8235 - loss: 0.5217 - val_accuracy: 0.7088 - val_loss: 0.7132
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8246 - loss: 0.5065 - val_accuracy: 0.6758 - val_loss: 0.7205
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8029 - loss: 0.5311 - val_accuracy: 0.6978 - val_loss: 0.7102
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
# Subject Subject19
# Accuracy     : 0.6978
# Precision    : 0.7012
# Recall       : 0.6978
# F1 Score     : 0.6907
# Specificity  : 0.7951
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.4539 - loss: 1.2749 - val_accuracy: 0.5191 - val_loss: 1.0741
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.5347 - loss: 1.0758 - val_accuracy: 0.5792 - val_loss: 0.9779
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6018 - loss: 0.9322 - val_accuracy: 0.6175 - val_loss: 0.9278
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6245 - loss: 0.8919 - val_accuracy: 0.5847 - val_loss: 0.9348
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6223 - loss: 0.8830 - val_accuracy: 0.6230 - val_loss: 0.8942
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6390 - loss: 0.8598 - val_accuracy: 0.6284 - val_loss: 0.8833
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6786 - loss: 0.8331 - val_accuracy: 0.6393 - val_loss: 0.8692
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.6748 - loss: 0.7858 - val_accuracy: 0.6503 - val_loss: 0.8800
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7403 - loss: 0.7132 - val_accuracy: 0.6175 - val_loss: 0.8746
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.6776 - loss: 0.7594 - val_accuracy: 0.6776 - val_loss: 0.8486
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7216 - loss: 0.6959 - val_accuracy: 0.6721 - val_loss: 0.8430
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7394 - loss: 0.6913 - val_accuracy: 0.6667 - val_loss: 0.8272
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7428 - loss: 0.6921 - val_accuracy: 0.6503 - val_loss: 0.8225
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7648 - loss: 0.6209 - val_accuracy: 0.6667 - val_loss: 0.8150
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7697 - loss: 0.6028 - val_accuracy: 0.6448 - val_loss: 0.8940
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7512 - loss: 0.6078 - val_accuracy: 0.6503 - val_loss: 0.8365
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7744 - loss: 0.5867 - val_accuracy: 0.6612 - val_loss: 0.8492
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.8090 - loss: 0.5184 - val_accuracy: 0.6667 - val_loss: 0.8266
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.8107 - loss: 0.4989 - val_accuracy: 0.6612 - val_loss: 0.8341
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8246 - loss: 0.4613 - val_accuracy: 0.6230 - val_loss: 0.9054
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#
# Subject Subject2
# Accuracy     : 0.6230
# Precision    : 0.6625
# Recall       : 0.6230
# F1 Score     : 0.5950
# Specificity  : 0.8155
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.4459 - loss: 1.2508 - val_accuracy: 0.5273 - val_loss: 1.0476
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.5244 - loss: 1.0149 - val_accuracy: 0.5591 - val_loss: 0.9547
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.5797 - loss: 0.9526 - val_accuracy: 0.5636 - val_loss: 0.9496
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.5443 - loss: 0.9515 - val_accuracy: 0.5545 - val_loss: 0.9630
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6063 - loss: 0.8835 - val_accuracy: 0.5682 - val_loss: 0.8966
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.6573 - loss: 0.8190 - val_accuracy: 0.5909 - val_loss: 0.8896
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6496 - loss: 0.8420 - val_accuracy: 0.5909 - val_loss: 0.8836
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.6362 - loss: 0.7987 - val_accuracy: 0.6182 - val_loss: 0.8845
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.6728 - loss: 0.7691 - val_accuracy: 0.6045 - val_loss: 0.8712
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.6979 - loss: 0.7163 - val_accuracy: 0.5818 - val_loss: 0.8748
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.7110 - loss: 0.6900 - val_accuracy: 0.6045 - val_loss: 0.8613
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7475 - loss: 0.6812 - val_accuracy: 0.6227 - val_loss: 0.8445
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7299 - loss: 0.6454 - val_accuracy: 0.6227 - val_loss: 0.8712
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.7687 - loss: 0.6288 - val_accuracy: 0.6045 - val_loss: 0.8714
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7678 - loss: 0.5748 - val_accuracy: 0.5955 - val_loss: 0.9070
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.7804 - loss: 0.5855 - val_accuracy: 0.5955 - val_loss: 0.8797
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7458 - loss: 0.5960 - val_accuracy: 0.6227 - val_loss: 0.8623
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.7884 - loss: 0.5366 - val_accuracy: 0.6273 - val_loss: 0.9237
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.8157 - loss: 0.5151 - val_accuracy: 0.6227 - val_loss: 0.8695
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8385 - loss: 0.4616 - val_accuracy: 0.6227 - val_loss: 0.8671
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject20
# Accuracy     : 0.6227
# Precision    : 0.6123
# Recall       : 0.6227
# F1 Score     : 0.6159
# Specificity  : 0.7938
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.4577 - loss: 1.1839 - val_accuracy: 0.5961 - val_loss: 0.9192
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.6024 - loss: 0.9480 - val_accuracy: 0.6502 - val_loss: 0.8135
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6187 - loss: 0.8758 - val_accuracy: 0.6650 - val_loss: 0.8001
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6417 - loss: 0.8069 - val_accuracy: 0.6897 - val_loss: 0.7577
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6839 - loss: 0.7701 - val_accuracy: 0.6995 - val_loss: 0.7605
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7141 - loss: 0.7335 - val_accuracy: 0.7143 - val_loss: 0.7254
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.6955 - loss: 0.6994 - val_accuracy: 0.7192 - val_loss: 0.7102
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6848 - loss: 0.7405 - val_accuracy: 0.7291 - val_loss: 0.6898
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.6978 - loss: 0.6751 - val_accuracy: 0.7635 - val_loss: 0.6976
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7642 - loss: 0.6306 - val_accuracy: 0.7192 - val_loss: 0.7093
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7644 - loss: 0.6190 - val_accuracy: 0.7537 - val_loss: 0.6801
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7681 - loss: 0.6255 - val_accuracy: 0.7340 - val_loss: 0.6754
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7738 - loss: 0.6099 - val_accuracy: 0.7340 - val_loss: 0.6608
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7838 - loss: 0.5924 - val_accuracy: 0.7340 - val_loss: 0.6802
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7997 - loss: 0.5487 - val_accuracy: 0.7635 - val_loss: 0.6225
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.7800 - loss: 0.5113 - val_accuracy: 0.7438 - val_loss: 0.6247
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.8271 - loss: 0.4989 - val_accuracy: 0.7635 - val_loss: 0.6348
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7870 - loss: 0.5401 - val_accuracy: 0.7586 - val_loss: 0.6520
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8456 - loss: 0.4632 - val_accuracy: 0.7389 - val_loss: 0.6264
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8357 - loss: 0.4457 - val_accuracy: 0.7340 - val_loss: 0.6384
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Subject Subject3
# Accuracy     : 0.7340
# Precision    : 0.7255
# Recall       : 0.7340
# F1 Score     : 0.7187
# Specificity  : 0.8212
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - accuracy: 0.4750 - loss: 1.2498 - val_accuracy: 0.5550 - val_loss: 0.9306
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.5944 - loss: 0.9562 - val_accuracy: 0.6550 - val_loss: 0.8304
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6486 - loss: 0.8351 - val_accuracy: 0.7200 - val_loss: 0.7468
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6820 - loss: 0.7626 - val_accuracy: 0.7250 - val_loss: 0.7027
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7448 - loss: 0.7066 - val_accuracy: 0.7200 - val_loss: 0.7084
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7319 - loss: 0.7088 - val_accuracy: 0.7400 - val_loss: 0.7123
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7388 - loss: 0.6904 - val_accuracy: 0.7550 - val_loss: 0.6767
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7405 - loss: 0.6641 - val_accuracy: 0.7350 - val_loss: 0.6705
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7803 - loss: 0.5702 - val_accuracy: 0.7250 - val_loss: 0.6740
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.7626 - loss: 0.6017 - val_accuracy: 0.7600 - val_loss: 0.6582
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7628 - loss: 0.5833 - val_accuracy: 0.7350 - val_loss: 0.7179
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7736 - loss: 0.5633 - val_accuracy: 0.7450 - val_loss: 0.6471
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.8055 - loss: 0.5294 - val_accuracy: 0.7500 - val_loss: 0.5984
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8167 - loss: 0.5031 - val_accuracy: 0.7550 - val_loss: 0.5910
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8429 - loss: 0.4752 - val_accuracy: 0.7550 - val_loss: 0.6478
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8107 - loss: 0.5148 - val_accuracy: 0.7500 - val_loss: 0.5876
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.8375 - loss: 0.4611 - val_accuracy: 0.7500 - val_loss: 0.6503
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8568 - loss: 0.4132 - val_accuracy: 0.7500 - val_loss: 0.6132
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8278 - loss: 0.4416 - val_accuracy: 0.7500 - val_loss: 0.5798
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.8463 - loss: 0.3971 - val_accuracy: 0.7550 - val_loss: 0.5844
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Subject Subject4
# Accuracy     : 0.7550
# Precision    : 0.7538
# Recall       : 0.7550
# F1 Score     : 0.7525
# Specificity  : 0.8965
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - accuracy: 0.4157 - loss: 1.3386 - val_accuracy: 0.5303 - val_loss: 1.0802
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.5728 - loss: 1.0025 - val_accuracy: 0.6465 - val_loss: 0.8946
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.6144 - loss: 0.8813 - val_accuracy: 0.6212 - val_loss: 0.8401
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.6316 - loss: 0.8368 - val_accuracy: 0.6717 - val_loss: 0.8081
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.6946 - loss: 0.7462 - val_accuracy: 0.6667 - val_loss: 0.7943
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6880 - loss: 0.7296 - val_accuracy: 0.6414 - val_loss: 0.8060
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.7018 - loss: 0.7141 - val_accuracy: 0.6717 - val_loss: 0.7807
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7229 - loss: 0.6736 - val_accuracy: 0.6414 - val_loss: 0.7557
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7117 - loss: 0.6911 - val_accuracy: 0.6717 - val_loss: 0.7535
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.7439 - loss: 0.6393 - val_accuracy: 0.6818 - val_loss: 0.7646
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7626 - loss: 0.6232 - val_accuracy: 0.6566 - val_loss: 0.7459
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7628 - loss: 0.6244 - val_accuracy: 0.6768 - val_loss: 0.7515
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.7558 - loss: 0.5840 - val_accuracy: 0.6717 - val_loss: 0.7442
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7758 - loss: 0.5793 - val_accuracy: 0.6768 - val_loss: 0.7434
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7965 - loss: 0.5073 - val_accuracy: 0.6818 - val_loss: 0.7480
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7974 - loss: 0.5175 - val_accuracy: 0.6869 - val_loss: 0.7621
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.8090 - loss: 0.5048 - val_accuracy: 0.6818 - val_loss: 0.7490
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8275 - loss: 0.4648 - val_accuracy: 0.6869 - val_loss: 0.7336
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8498 - loss: 0.4380 - val_accuracy: 0.6717 - val_loss: 0.7246
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8520 - loss: 0.4275 - val_accuracy: 0.6869 - val_loss: 0.7636
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Subject Subject5
# Accuracy     : 0.6869
# Precision    : 0.7059
# Recall       : 0.6869
# F1 Score     : 0.6909
# Specificity  : 0.9022
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - accuracy: 0.4593 - loss: 1.2470 - val_accuracy: 0.5110 - val_loss: 1.1702
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5408 - loss: 1.1185 - val_accuracy: 0.5220 - val_loss: 1.0784
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.5636 - loss: 1.0614 - val_accuracy: 0.5220 - val_loss: 1.0380
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.5870 - loss: 0.9653 - val_accuracy: 0.5220 - val_loss: 1.0403
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.5712 - loss: 0.9470 - val_accuracy: 0.5275 - val_loss: 1.0114
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6269 - loss: 0.8997 - val_accuracy: 0.5495 - val_loss: 0.9947
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.6115 - loss: 0.9176 - val_accuracy: 0.5220 - val_loss: 1.0032
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6451 - loss: 0.8154 - val_accuracy: 0.5659 - val_loss: 0.9945
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.6677 - loss: 0.8411 - val_accuracy: 0.5714 - val_loss: 0.9717
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6575 - loss: 0.8009 - val_accuracy: 0.5879 - val_loss: 0.9869
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6969 - loss: 0.7402 - val_accuracy: 0.5934 - val_loss: 0.9389
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.7052 - loss: 0.7067 - val_accuracy: 0.6099 - val_loss: 0.9407
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7785 - loss: 0.6216 - val_accuracy: 0.6044 - val_loss: 0.9580
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.7037 - loss: 0.6972 - val_accuracy: 0.6154 - val_loss: 0.9132
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7425 - loss: 0.6312 - val_accuracy: 0.6099 - val_loss: 0.9095
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7791 - loss: 0.5779 - val_accuracy: 0.6044 - val_loss: 0.9221
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7543 - loss: 0.6046 - val_accuracy: 0.5879 - val_loss: 0.9452
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7837 - loss: 0.5523 - val_accuracy: 0.5824 - val_loss: 0.9343
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.7907 - loss: 0.5410 - val_accuracy: 0.5879 - val_loss: 0.9629
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7967 - loss: 0.5373 - val_accuracy: 0.6264 - val_loss: 0.9267
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Subject Subject6
# Accuracy     : 0.6264
# Precision    : 0.6154
# Recall       : 0.6264
# F1 Score     : 0.6151
# Specificity  : 0.7743
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.4619 - loss: 1.2040 - val_accuracy: 0.5967 - val_loss: 0.9275
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.5701 - loss: 0.9166 - val_accuracy: 0.6077 - val_loss: 0.8732
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6404 - loss: 0.8447 - val_accuracy: 0.6685 - val_loss: 0.8616
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.6901 - loss: 0.7552 - val_accuracy: 0.6133 - val_loss: 0.8604
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6597 - loss: 0.8108 - val_accuracy: 0.6575 - val_loss: 0.8282
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.6873 - loss: 0.7225 - val_accuracy: 0.6796 - val_loss: 0.8031
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7045 - loss: 0.7170 - val_accuracy: 0.6685 - val_loss: 0.7832
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6843 - loss: 0.7556 - val_accuracy: 0.6796 - val_loss: 0.7823
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7415 - loss: 0.6489 - val_accuracy: 0.6575 - val_loss: 0.7656
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7660 - loss: 0.6287 - val_accuracy: 0.7017 - val_loss: 0.7666
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7468 - loss: 0.5972 - val_accuracy: 0.6740 - val_loss: 0.7502
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7952 - loss: 0.5172 - val_accuracy: 0.6740 - val_loss: 0.7824
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7849 - loss: 0.5738 - val_accuracy: 0.6740 - val_loss: 0.7811
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7797 - loss: 0.5606 - val_accuracy: 0.6796 - val_loss: 0.7652
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.8035 - loss: 0.5174 - val_accuracy: 0.7072 - val_loss: 0.7117
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8389 - loss: 0.4597 - val_accuracy: 0.7403 - val_loss: 0.7157
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8456 - loss: 0.4432 - val_accuracy: 0.7182 - val_loss: 0.7217
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8441 - loss: 0.4115 - val_accuracy: 0.7127 - val_loss: 0.7556
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8365 - loss: 0.4144 - val_accuracy: 0.7735 - val_loss: 0.6901
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8760 - loss: 0.3672 - val_accuracy: 0.6906 - val_loss: 0.7227
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Subject Subject7
# Accuracy     : 0.6906
# Precision    : 0.7549
# Recall       : 0.6906
# F1 Score     : 0.7053
# Specificity  : 0.9016
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - accuracy: 0.4866 - loss: 1.2129 - val_accuracy: 0.5220 - val_loss: 1.1351
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.5081 - loss: 1.1513 - val_accuracy: 0.5220 - val_loss: 1.0580
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.5269 - loss: 1.0484 - val_accuracy: 0.5495 - val_loss: 0.9896
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5902 - loss: 0.9499 - val_accuracy: 0.5714 - val_loss: 0.9688
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6422 - loss: 0.8976 - val_accuracy: 0.6264 - val_loss: 0.9401
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6401 - loss: 0.8626 - val_accuracy: 0.5549 - val_loss: 0.9510
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.6474 - loss: 0.8366 - val_accuracy: 0.6044 - val_loss: 0.8910
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.6560 - loss: 0.8271 - val_accuracy: 0.6319 - val_loss: 0.8598
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.7055 - loss: 0.7272 - val_accuracy: 0.6264 - val_loss: 0.8588
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6668 - loss: 0.8000 - val_accuracy: 0.5934 - val_loss: 0.8567
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7101 - loss: 0.7115 - val_accuracy: 0.6538 - val_loss: 0.8400
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7314 - loss: 0.6660 - val_accuracy: 0.6044 - val_loss: 0.8427
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7512 - loss: 0.6762 - val_accuracy: 0.6264 - val_loss: 0.8177
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7305 - loss: 0.6179 - val_accuracy: 0.6648 - val_loss: 0.7858
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.7554 - loss: 0.5717 - val_accuracy: 0.6703 - val_loss: 0.7798
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7502 - loss: 0.6310 - val_accuracy: 0.6758 - val_loss: 0.7722
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7706 - loss: 0.5822 - val_accuracy: 0.6923 - val_loss: 0.7502
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8233 - loss: 0.5102 - val_accuracy: 0.6648 - val_loss: 0.7510
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8168 - loss: 0.5169 - val_accuracy: 0.6319 - val_loss: 0.7707
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8144 - loss: 0.5012 - val_accuracy: 0.6374 - val_loss: 0.7499
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#
# Subject Subject8
# Accuracy     : 0.6374
# Precision    : 0.6107
# Recall       : 0.6374
# F1 Score     : 0.6192
# Specificity  : 0.7924
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.5184 - loss: 1.1210 - val_accuracy: 0.7033 - val_loss: 0.7396
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6614 - loss: 0.7806 - val_accuracy: 0.7253 - val_loss: 0.6879
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.7207 - loss: 0.7038 - val_accuracy: 0.7253 - val_loss: 0.6877
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6950 - loss: 0.7037 - val_accuracy: 0.6978 - val_loss: 0.6883
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7071 - loss: 0.6767 - val_accuracy: 0.6978 - val_loss: 0.6703
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.7386 - loss: 0.6628 - val_accuracy: 0.7253 - val_loss: 0.6426
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7430 - loss: 0.6164 - val_accuracy: 0.7033 - val_loss: 0.6489
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7791 - loss: 0.5961 - val_accuracy: 0.7308 - val_loss: 0.6368
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7852 - loss: 0.5528 - val_accuracy: 0.7418 - val_loss: 0.6358
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8024 - loss: 0.5164 - val_accuracy: 0.7582 - val_loss: 0.6224
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.8240 - loss: 0.5039 - val_accuracy: 0.7473 - val_loss: 0.6293
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.8204 - loss: 0.5269 - val_accuracy: 0.7692 - val_loss: 0.6247
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8104 - loss: 0.5044 - val_accuracy: 0.7363 - val_loss: 0.6497
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8393 - loss: 0.4741 - val_accuracy: 0.7692 - val_loss: 0.6066
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.8374 - loss: 0.4459 - val_accuracy: 0.7582 - val_loss: 0.6116
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.8425 - loss: 0.4640 - val_accuracy: 0.7582 - val_loss: 0.6492
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8913 - loss: 0.3919 - val_accuracy: 0.7637 - val_loss: 0.6434
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.8585 - loss: 0.3872 - val_accuracy: 0.7527 - val_loss: 0.6540
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.8793 - loss: 0.3811 - val_accuracy: 0.7802 - val_loss: 0.6262
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8801 - loss: 0.3731 - val_accuracy: 0.7582 - val_loss: 0.6278
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Subject Subject9
# Accuracy     : 0.7582
# Precision    : 0.7691
# Recall       : 0.7582
# F1 Score     : 0.7390
# Specificity  : 0.8606
#
# === Summary Metrics ===
#
# === Per-Subject Metrics ===
# Average Per-Subject Accuracy: 0.6991422583387612
# Average Per-Subject Precision: 0.7018883415610964
# Average Per-Subject Recall: 0.6991422583387612
# Average Per-Subject F1 Score: 0.6890350144228514
# Average Per-Subject Specificity: 0.8413694059995068
#
# Results saved to 'intra_subject_results_summary.txt'

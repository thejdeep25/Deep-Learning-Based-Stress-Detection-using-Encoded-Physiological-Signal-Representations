# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cleaned/cleaned_dataset.csv

# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.0 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import pandas as pd
from pyts.image import MarkovTransitionField
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import warnings
from collections import Counter
import gc
from tensorflow.keras import backend as K
from pyts.image import GramianAngularField

warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/kaggle/input/cleaned/cleaned_dataset.csv')  # Replace with your path
df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.sort_values(['SubjectID', 'DateTime'])

# Preprocess features
feature_cols = ['AccX', 'AccY', 'AccZ', 'Temp', 'EDA', 'HeartRate', 'SpO2']
target_col = 'Label'

scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

def create_windows(df, feature_cols, target_col, window_size=100, step=20):
    X = []
    y = []
    for subject_id, subject_df in df.groupby('SubjectID'):
        subject_data = subject_df.reset_index(drop=True)
        features = subject_data[feature_cols].values
        labels = subject_data[target_col].values
        for start in range(0, len(features) - window_size, step):
            end = start + window_size
            window_x = features[start:end]
            window_y = labels[start:end]
            label = Counter(window_y).most_common(1)[0][0]
            X.append(window_x)
            y.append(label)
    return np.array(X), np.array(y)

X, y = create_windows(df, feature_cols, target_col)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Convert time-series to images using MTF
def time_series_to_image_gaf(sample, image_size=64, method='difference'):
    gaf = GramianAngularField(image_size=image_size, method=method)
    img_list = []
    for i in range(sample.shape[1]):
        ts = sample[:, i]
        img = gaf.fit_transform(ts.reshape(1, -1))[0]
        img_list.append(img)
    img = np.stack(img_list, axis=-1)
    return img

image_data = np.array([time_series_to_image_gaf(seq) for seq in X])


# CNN model
def build_image_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Evaluation
def evaluate_model(model, X_test, y_test, label_encoder, title="Model"):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    specificity_per_class = []
    for i in range(len(cm)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(np.delete(cm, i, axis=0)[:, i])
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        specificity_per_class.append(specificity)
    weighted_specificity = np.average(specificity_per_class, weights=np.bincount(y_true_classes))

    print(f"\n{title}")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"F1 Score     : {f1:.4f}")
    print(f"Specificity  : {weighted_specificity:.4f}")

    return accuracy, precision, recall, f1, weighted_specificity

# Intra-Subject Classification: Ensure data consistency for splitting
results_subjectwise = {}
for subject_id, subject_df in df.groupby('SubjectID'):
    X_subject, y_subject = create_windows(subject_df, feature_cols, target_col)
    
    # Convert time-series data to images for subject-wise classification
    image_data_subject = np.array([time_series_to_image_gaf(seq) for seq in X_subject])
    
    # Ensure labels and features have the same length for splitting
    y_subject_encoded = le.transform(y_subject)
    
    X_train_subj, X_test_subj, y_train_subj, y_test_subj = train_test_split(
        image_data_subject, to_categorical(y_subject_encoded), test_size=0.2, stratify=y_subject_encoded, random_state=42
    )
    
    img_model_subj = build_image_model(X_train_subj.shape[1:], y_cat.shape[1])
    img_model_subj.fit(X_train_subj, y_train_subj, validation_data=(X_test_subj, y_test_subj),
                       epochs=20, batch_size=32)
    
    acc, precision, recall, f1, specificity = evaluate_model(img_model_subj, X_test_subj, y_test_subj, le, title=f"Subject {subject_id}")
    results_subjectwise[subject_id] = {'Accuracy': acc, 'Precision': precision, 'Recall': recall, 'F1': f1, 'Specificity': specificity}
# === Summary ===

print("\n=== Summary Metrics ===")

# Average Per-Subject Metrics
print("\n=== Per-Subject Metrics ===")
print("Average Per-Subject Accuracy:", np.mean([result['Accuracy'] for result in results_subjectwise.values()]))
print("Average Per-Subject Precision:", np.mean([result['Precision'] for result in results_subjectwise.values()]))
print("Average Per-Subject Recall:", np.mean([result['Recall'] for result in results_subjectwise.values()]))
print("Average Per-Subject F1 Score:", np.mean([result['F1'] for result in results_subjectwise.values()]))
print("Average Per-Subject Specificity:", np.mean([result['Specificity'] for result in results_subjectwise.values()]))

# Save Intra-Subject Results
with open("/kaggle/working/intra_subject_results.txt", "w") as f:
    f.write("=== Intra-Subject Evaluation Results ===\n\n")
    for subject_id, metrics in results_subjectwise.items():
        f.write(f"Subject {subject_id}:\n")
        for metric_name, metric_value in metrics.items():
            f.write(f"  {metric_name}: {metric_value:.4f}\n")
        f.write("\n")

    f.write("=== Average Intra-Subject Metrics ===\n")
    f.write(f"Accuracy     : {np.mean([res['Accuracy'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Precision    : {np.mean([res['Precision'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Recall       : {np.mean([res['Recall'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"F1 Score     : {np.mean([res['F1'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Specificity  : {np.mean([res['Specificity'] for res in results_subjectwise.values()]):.4f}\n")
# Out:
# 2025-04-14 03:47:40.695971: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744602460.953551      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744602461.033388      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-14 03:49:18.586168: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.4774 - loss: 1.2553 - val_accuracy: 0.5381 - val_loss: 1.0786
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.5268 - loss: 1.0984 - val_accuracy: 0.5736 - val_loss: 0.9884
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.5769 - loss: 1.0028 - val_accuracy: 0.6193 - val_loss: 0.9372
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5774 - loss: 0.9809 - val_accuracy: 0.6345 - val_loss: 0.9029
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6202 - loss: 0.8888 - val_accuracy: 0.6447 - val_loss: 0.8566
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6476 - loss: 0.8343 - val_accuracy: 0.6599 - val_loss: 0.8083
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7053 - loss: 0.7668 - val_accuracy: 0.6904 - val_loss: 0.7674
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7158 - loss: 0.7524 - val_accuracy: 0.7157 - val_loss: 0.7204
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7366 - loss: 0.6675 - val_accuracy: 0.7360 - val_loss: 0.6654
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7626 - loss: 0.6164 - val_accuracy: 0.7411 - val_loss: 0.6358
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7712 - loss: 0.5986 - val_accuracy: 0.7411 - val_loss: 0.6185
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8177 - loss: 0.5067 - val_accuracy: 0.7665 - val_loss: 0.6025
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8080 - loss: 0.4769 - val_accuracy: 0.7462 - val_loss: 0.6629
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8062 - loss: 0.4960 - val_accuracy: 0.7970 - val_loss: 0.5349
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8607 - loss: 0.4070 - val_accuracy: 0.7868 - val_loss: 0.5349
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.8515 - loss: 0.4134 - val_accuracy: 0.7868 - val_loss: 0.5421
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8513 - loss: 0.3732 - val_accuracy: 0.7563 - val_loss: 0.5961
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8433 - loss: 0.4157 - val_accuracy: 0.8020 - val_loss: 0.4678
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8617 - loss: 0.3646 - val_accuracy: 0.7970 - val_loss: 0.4480
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8831 - loss: 0.3325 - val_accuracy: 0.7970 - val_loss: 0.4443
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Subject Subject1
# Accuracy     : 0.7970
# Precision    : 0.8042
# Recall       : 0.7970
# F1 Score     : 0.7991
# Specificity  : 0.9118
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - accuracy: 0.4444 - loss: 1.2626 - val_accuracy: 0.5220 - val_loss: 1.1454
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.5137 - loss: 1.1273 - val_accuracy: 0.5275 - val_loss: 1.0747
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.5638 - loss: 1.0040 - val_accuracy: 0.5495 - val_loss: 0.9988
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.6220 - loss: 0.9150 - val_accuracy: 0.5989 - val_loss: 0.9174
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6842 - loss: 0.8053 - val_accuracy: 0.5989 - val_loss: 0.8876
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6702 - loss: 0.7946 - val_accuracy: 0.6758 - val_loss: 0.7851
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7243 - loss: 0.6866 - val_accuracy: 0.7143 - val_loss: 0.7273
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7754 - loss: 0.6549 - val_accuracy: 0.7363 - val_loss: 0.6591
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7892 - loss: 0.6015 - val_accuracy: 0.7527 - val_loss: 0.6166
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8331 - loss: 0.5280 - val_accuracy: 0.7692 - val_loss: 0.5605
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8266 - loss: 0.4793 - val_accuracy: 0.7802 - val_loss: 0.5148
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8801 - loss: 0.3897 - val_accuracy: 0.7857 - val_loss: 0.4963
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8667 - loss: 0.3789 - val_accuracy: 0.8187 - val_loss: 0.4686
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8753 - loss: 0.3535 - val_accuracy: 0.8187 - val_loss: 0.4649
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.8933 - loss: 0.3496 - val_accuracy: 0.8407 - val_loss: 0.4213
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8753 - loss: 0.3214 - val_accuracy: 0.8022 - val_loss: 0.4239
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8793 - loss: 0.3147 - val_accuracy: 0.8297 - val_loss: 0.4480
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9245 - loss: 0.2627 - val_accuracy: 0.8516 - val_loss: 0.4006
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9212 - loss: 0.2461 - val_accuracy: 0.8352 - val_loss: 0.4012
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9129 - loss: 0.2675 - val_accuracy: 0.8187 - val_loss: 0.3805
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject10
# Accuracy     : 0.8187
# Precision    : 0.8149
# Recall       : 0.8187
# F1 Score     : 0.8108
# Specificity  : 0.9298
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.4601 - loss: 1.2824 - val_accuracy: 0.4956 - val_loss: 1.1610
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5037 - loss: 1.1302 - val_accuracy: 0.4956 - val_loss: 1.1171
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.5268 - loss: 1.0606 - val_accuracy: 0.5088 - val_loss: 1.0301
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.5352 - loss: 1.0037 - val_accuracy: 0.5175 - val_loss: 0.9999
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5386 - loss: 0.9814 - val_accuracy: 0.5658 - val_loss: 0.9407
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - accuracy: 0.6014 - loss: 0.9157 - val_accuracy: 0.5833 - val_loss: 0.8912
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6594 - loss: 0.8391 - val_accuracy: 0.6404 - val_loss: 0.8297
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.6546 - loss: 0.8002 - val_accuracy: 0.6667 - val_loss: 0.7840
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7245 - loss: 0.7051 - val_accuracy: 0.6667 - val_loss: 0.7391
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.6974 - loss: 0.7300 - val_accuracy: 0.6623 - val_loss: 0.7316
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7295 - loss: 0.6660 - val_accuracy: 0.6842 - val_loss: 0.7256
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7516 - loss: 0.6388 - val_accuracy: 0.6930 - val_loss: 0.7168
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.7603 - loss: 0.5967 - val_accuracy: 0.6842 - val_loss: 0.7242
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7438 - loss: 0.5994 - val_accuracy: 0.6842 - val_loss: 0.6616
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.7616 - loss: 0.5863 - val_accuracy: 0.7105 - val_loss: 0.6591
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.7638 - loss: 0.5974 - val_accuracy: 0.6798 - val_loss: 0.6435
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7813 - loss: 0.5543 - val_accuracy: 0.6886 - val_loss: 0.7057
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.8047 - loss: 0.5120 - val_accuracy: 0.7281 - val_loss: 0.6383
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.8323 - loss: 0.4698 - val_accuracy: 0.7237 - val_loss: 0.6170
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8067 - loss: 0.4854 - val_accuracy: 0.7281 - val_loss: 0.6588
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Subject Subject11
# Accuracy     : 0.7281
# Precision    : 0.7546
# Recall       : 0.7281
# F1 Score     : 0.6914
# Specificity  : 0.7698
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - accuracy: 0.4659 - loss: 1.2617 - val_accuracy: 0.5297 - val_loss: 1.1726
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.5566 - loss: 1.1449 - val_accuracy: 0.5297 - val_loss: 1.1502
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.5213 - loss: 1.1145 - val_accuracy: 0.5297 - val_loss: 1.1109
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.5507 - loss: 1.0682 - val_accuracy: 0.5405 - val_loss: 1.1044
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.6068 - loss: 0.9918 - val_accuracy: 0.5568 - val_loss: 1.0353
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.5654 - loss: 0.9571 - val_accuracy: 0.5568 - val_loss: 0.9576
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.6402 - loss: 0.8450 - val_accuracy: 0.6162 - val_loss: 0.9058
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.6928 - loss: 0.7885 - val_accuracy: 0.6649 - val_loss: 0.8537
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7250 - loss: 0.7732 - val_accuracy: 0.6865 - val_loss: 0.8153
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7425 - loss: 0.7047 - val_accuracy: 0.6811 - val_loss: 0.8060
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7580 - loss: 0.6515 - val_accuracy: 0.6324 - val_loss: 0.8077
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7695 - loss: 0.6375 - val_accuracy: 0.7081 - val_loss: 0.7278
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8135 - loss: 0.5838 - val_accuracy: 0.6973 - val_loss: 0.7009
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8280 - loss: 0.5131 - val_accuracy: 0.7297 - val_loss: 0.7080
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8326 - loss: 0.5155 - val_accuracy: 0.7135 - val_loss: 0.6852
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8204 - loss: 0.4885 - val_accuracy: 0.7243 - val_loss: 0.7057
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8794 - loss: 0.4101 - val_accuracy: 0.7351 - val_loss: 0.6592
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8539 - loss: 0.4276 - val_accuracy: 0.7730 - val_loss: 0.6017
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8819 - loss: 0.3527 - val_accuracy: 0.7243 - val_loss: 0.6569
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.8617 - loss: 0.4006 - val_accuracy: 0.7568 - val_loss: 0.5991
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject12
# Accuracy     : 0.7568
# Precision    : 0.7584
# Recall       : 0.7568
# F1 Score     : 0.7465
# Specificity  : 0.8073
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.4467 - loss: 1.2370 - val_accuracy: 0.5220 - val_loss: 1.0612
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.5658 - loss: 1.0134 - val_accuracy: 0.6374 - val_loss: 0.9754
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.6439 - loss: 0.9253 - val_accuracy: 0.6374 - val_loss: 0.9130
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6554 - loss: 0.8455 - val_accuracy: 0.6429 - val_loss: 0.8590
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.6936 - loss: 0.7795 - val_accuracy: 0.6923 - val_loss: 0.8120
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.7036 - loss: 0.7331 - val_accuracy: 0.6978 - val_loss: 0.7921
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7251 - loss: 0.6992 - val_accuracy: 0.7253 - val_loss: 0.7502
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.7491 - loss: 0.6554 - val_accuracy: 0.6868 - val_loss: 0.7356
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8049 - loss: 0.5632 - val_accuracy: 0.7527 - val_loss: 0.6852
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7723 - loss: 0.5560 - val_accuracy: 0.7527 - val_loss: 0.6558
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8444 - loss: 0.4586 - val_accuracy: 0.7637 - val_loss: 0.6265
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8223 - loss: 0.4536 - val_accuracy: 0.7088 - val_loss: 0.6074
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8678 - loss: 0.3854 - val_accuracy: 0.7802 - val_loss: 0.5918
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.8717 - loss: 0.4203 - val_accuracy: 0.7308 - val_loss: 0.5775
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8694 - loss: 0.3988 - val_accuracy: 0.7692 - val_loss: 0.5421
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8994 - loss: 0.3322 - val_accuracy: 0.7582 - val_loss: 0.5222
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9065 - loss: 0.3100 - val_accuracy: 0.7582 - val_loss: 0.5644
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8747 - loss: 0.3625 - val_accuracy: 0.8077 - val_loss: 0.5538
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8991 - loss: 0.3233 - val_accuracy: 0.7582 - val_loss: 0.5306
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8959 - loss: 0.2936 - val_accuracy: 0.7967 - val_loss: 0.4931
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Subject Subject13
# Accuracy     : 0.7967
# Precision    : 0.8151
# Recall       : 0.7967
# F1 Score     : 0.8017
# Specificity  : 0.9198
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - accuracy: 0.4837 - loss: 1.2477 - val_accuracy: 0.5220 - val_loss: 1.1561
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.5476 - loss: 1.1294 - val_accuracy: 0.5275 - val_loss: 1.1030
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.5529 - loss: 1.0755 - val_accuracy: 0.5879 - val_loss: 1.0784
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.5568 - loss: 1.0405 - val_accuracy: 0.5330 - val_loss: 0.9820
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.6305 - loss: 0.9018 - val_accuracy: 0.6538 - val_loss: 0.8939
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.6801 - loss: 0.8332 - val_accuracy: 0.6978 - val_loss: 0.7997
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7120 - loss: 0.7544 - val_accuracy: 0.7473 - val_loss: 0.7264
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7735 - loss: 0.6828 - val_accuracy: 0.7692 - val_loss: 0.6677
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8140 - loss: 0.5738 - val_accuracy: 0.8297 - val_loss: 0.6790
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8280 - loss: 0.5459 - val_accuracy: 0.8132 - val_loss: 0.5934
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8483 - loss: 0.4763 - val_accuracy: 0.8077 - val_loss: 0.5511
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8460 - loss: 0.4484 - val_accuracy: 0.8242 - val_loss: 0.5157
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8665 - loss: 0.3889 - val_accuracy: 0.8516 - val_loss: 0.4721
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8763 - loss: 0.3559 - val_accuracy: 0.8462 - val_loss: 0.4853
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9361 - loss: 0.2903 - val_accuracy: 0.8571 - val_loss: 0.4562
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9301 - loss: 0.2684 - val_accuracy: 0.8077 - val_loss: 0.5051
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8884 - loss: 0.3569 - val_accuracy: 0.8407 - val_loss: 0.4605
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8980 - loss: 0.3017 - val_accuracy: 0.8407 - val_loss: 0.4591
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.9374 - loss: 0.2357 - val_accuracy: 0.8571 - val_loss: 0.4307
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.9529 - loss: 0.2191 - val_accuracy: 0.8516 - val_loss: 0.4676
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject14
# Accuracy     : 0.8516
# Precision    : 0.8516
# Recall       : 0.8516
# F1 Score     : 0.8481
# Specificity  : 0.8869
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.4638 - loss: 1.2921 - val_accuracy: 0.5359 - val_loss: 1.1246
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.5852 - loss: 1.0651 - val_accuracy: 0.5691 - val_loss: 1.0435
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.5897 - loss: 1.0023 - val_accuracy: 0.5580 - val_loss: 0.9988
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.5979 - loss: 0.9614 - val_accuracy: 0.5691 - val_loss: 0.9762
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6254 - loss: 0.8743 - val_accuracy: 0.6022 - val_loss: 0.9852
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6720 - loss: 0.8675 - val_accuracy: 0.5912 - val_loss: 0.9613
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6554 - loss: 0.8712 - val_accuracy: 0.6133 - val_loss: 0.8983
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6877 - loss: 0.8160 - val_accuracy: 0.6133 - val_loss: 0.8722
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7135 - loss: 0.7354 - val_accuracy: 0.6906 - val_loss: 0.8481
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7600 - loss: 0.7094 - val_accuracy: 0.6630 - val_loss: 0.8368
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7675 - loss: 0.6545 - val_accuracy: 0.6851 - val_loss: 0.7905
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7841 - loss: 0.5945 - val_accuracy: 0.7238 - val_loss: 0.7384
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8274 - loss: 0.5047 - val_accuracy: 0.7403 - val_loss: 0.7267
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8046 - loss: 0.5203 - val_accuracy: 0.7403 - val_loss: 0.6933
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8368 - loss: 0.4399 - val_accuracy: 0.7459 - val_loss: 0.6997
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.8131 - loss: 0.4847 - val_accuracy: 0.7680 - val_loss: 0.6591
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8292 - loss: 0.4275 - val_accuracy: 0.7680 - val_loss: 0.6575
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8698 - loss: 0.3671 - val_accuracy: 0.7624 - val_loss: 0.6472
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8501 - loss: 0.3919 - val_accuracy: 0.7182 - val_loss: 0.6779
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8874 - loss: 0.3535 - val_accuracy: 0.7459 - val_loss: 0.6482
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject15
# Accuracy     : 0.7459
# Precision    : 0.7642
# Recall       : 0.7459
# F1 Score     : 0.7471
# Specificity  : 0.8870
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.4734 - loss: 1.2505 - val_accuracy: 0.5301 - val_loss: 1.0845
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.5658 - loss: 1.0888 - val_accuracy: 0.5683 - val_loss: 0.9891
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.5789 - loss: 0.9694 - val_accuracy: 0.5847 - val_loss: 0.9450
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.6166 - loss: 0.9220 - val_accuracy: 0.5792 - val_loss: 0.9048
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6523 - loss: 0.8597 - val_accuracy: 0.6448 - val_loss: 0.8502
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6703 - loss: 0.8222 - val_accuracy: 0.6940 - val_loss: 0.8124
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7285 - loss: 0.7506 - val_accuracy: 0.7049 - val_loss: 0.7671
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.7630 - loss: 0.6671 - val_accuracy: 0.7432 - val_loss: 0.7353
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7770 - loss: 0.6210 - val_accuracy: 0.7541 - val_loss: 0.6788
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.8401 - loss: 0.5191 - val_accuracy: 0.7814 - val_loss: 0.6641
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8266 - loss: 0.5411 - val_accuracy: 0.8087 - val_loss: 0.6289
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8505 - loss: 0.4918 - val_accuracy: 0.7596 - val_loss: 0.6037
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8593 - loss: 0.4616 - val_accuracy: 0.7596 - val_loss: 0.6110
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8611 - loss: 0.4214 - val_accuracy: 0.7869 - val_loss: 0.5996
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8910 - loss: 0.3565 - val_accuracy: 0.7486 - val_loss: 0.5967
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8408 - loss: 0.4271 - val_accuracy: 0.7760 - val_loss: 0.5680
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8665 - loss: 0.4014 - val_accuracy: 0.7705 - val_loss: 0.5555
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9092 - loss: 0.2853 - val_accuracy: 0.8087 - val_loss: 0.5162
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.9116 - loss: 0.3083 - val_accuracy: 0.7869 - val_loss: 0.5605
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.9075 - loss: 0.2836 - val_accuracy: 0.8033 - val_loss: 0.5418
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject16
# Accuracy     : 0.8033
# Precision    : 0.8285
# Recall       : 0.8033
# F1 Score     : 0.8001
# Specificity  : 0.8760
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.4448 - loss: 1.3047 - val_accuracy: 0.4951 - val_loss: 1.1812
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.5209 - loss: 1.1886 - val_accuracy: 0.5245 - val_loss: 1.1287
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.5210 - loss: 1.1531 - val_accuracy: 0.5539 - val_loss: 1.0937
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.5364 - loss: 1.0957 - val_accuracy: 0.5686 - val_loss: 1.0529
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6080 - loss: 0.9834 - val_accuracy: 0.5686 - val_loss: 1.0361
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.6222 - loss: 0.9452 - val_accuracy: 0.5735 - val_loss: 1.0041
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.6310 - loss: 0.9099 - val_accuracy: 0.5980 - val_loss: 0.9649
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6676 - loss: 0.8257 - val_accuracy: 0.5980 - val_loss: 0.9816
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6679 - loss: 0.8134 - val_accuracy: 0.5931 - val_loss: 0.9613
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.6916 - loss: 0.7358 - val_accuracy: 0.6520 - val_loss: 0.8635
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7287 - loss: 0.6933 - val_accuracy: 0.6667 - val_loss: 0.8481
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.7227 - loss: 0.7073 - val_accuracy: 0.6422 - val_loss: 0.8401
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7710 - loss: 0.6185 - val_accuracy: 0.6863 - val_loss: 0.8207
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8013 - loss: 0.5589 - val_accuracy: 0.6667 - val_loss: 0.8011
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7979 - loss: 0.5513 - val_accuracy: 0.6814 - val_loss: 0.8141
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8091 - loss: 0.5104 - val_accuracy: 0.6569 - val_loss: 0.8413
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8140 - loss: 0.4862 - val_accuracy: 0.6225 - val_loss: 0.8458
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.8399 - loss: 0.4643 - val_accuracy: 0.6716 - val_loss: 0.7995
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8673 - loss: 0.3908 - val_accuracy: 0.6618 - val_loss: 0.7818
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8681 - loss: 0.3700 - val_accuracy: 0.7010 - val_loss: 0.7612
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Subject Subject17
# Accuracy     : 0.7010
# Precision    : 0.7000
# Recall       : 0.7010
# F1 Score     : 0.6790
# Specificity  : 0.7759
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.4500 - loss: 1.2816 - val_accuracy: 0.5220 - val_loss: 1.1948
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5062 - loss: 1.2096 - val_accuracy: 0.5220 - val_loss: 1.1306
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.5194 - loss: 1.1169 - val_accuracy: 0.5549 - val_loss: 1.0518
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.5583 - loss: 1.0552 - val_accuracy: 0.5934 - val_loss: 0.9784
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.6915 - loss: 0.8841 - val_accuracy: 0.6209 - val_loss: 0.9059
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.6706 - loss: 0.8084 - val_accuracy: 0.6374 - val_loss: 0.8388
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7123 - loss: 0.7708 - val_accuracy: 0.6484 - val_loss: 0.8649
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.7132 - loss: 0.7169 - val_accuracy: 0.6923 - val_loss: 0.7683
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8071 - loss: 0.6237 - val_accuracy: 0.7253 - val_loss: 0.7462
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - accuracy: 0.8458 - loss: 0.5157 - val_accuracy: 0.6923 - val_loss: 0.7887
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8179 - loss: 0.4992 - val_accuracy: 0.7637 - val_loss: 0.6889
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8851 - loss: 0.4350 - val_accuracy: 0.7418 - val_loss: 0.6827
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8675 - loss: 0.4008 - val_accuracy: 0.7473 - val_loss: 0.6938
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8683 - loss: 0.4130 - val_accuracy: 0.7527 - val_loss: 0.7057
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8640 - loss: 0.3764 - val_accuracy: 0.7253 - val_loss: 0.7708
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8650 - loss: 0.4165 - val_accuracy: 0.7747 - val_loss: 0.6429
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9143 - loss: 0.3073 - val_accuracy: 0.7473 - val_loss: 0.6441
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.9317 - loss: 0.2810 - val_accuracy: 0.7857 - val_loss: 0.6501
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9130 - loss: 0.2624 - val_accuracy: 0.7692 - val_loss: 0.6468
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9175 - loss: 0.2593 - val_accuracy: 0.7637 - val_loss: 0.6747
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Subject Subject18
# Accuracy     : 0.7637
# Precision    : 0.7760
# Recall       : 0.7637
# F1 Score     : 0.7593
# Specificity  : 0.9104
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - accuracy: 0.4824 - loss: 1.2720 - val_accuracy: 0.5220 - val_loss: 1.2096
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5046 - loss: 1.2163 - val_accuracy: 0.5220 - val_loss: 1.1752
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5283 - loss: 1.1592 - val_accuracy: 0.5220 - val_loss: 1.1447
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5174 - loss: 1.1225 - val_accuracy: 0.5220 - val_loss: 1.1126
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.5494 - loss: 1.0850 - val_accuracy: 0.5440 - val_loss: 1.0993
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.5619 - loss: 1.0371 - val_accuracy: 0.5495 - val_loss: 1.0277
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.6016 - loss: 0.9753 - val_accuracy: 0.5769 - val_loss: 0.9930
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.5823 - loss: 0.9624 - val_accuracy: 0.5714 - val_loss: 0.9710
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.6421 - loss: 0.8796 - val_accuracy: 0.6648 - val_loss: 0.9023
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.6952 - loss: 0.7682 - val_accuracy: 0.6264 - val_loss: 0.9198
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7055 - loss: 0.7580 - val_accuracy: 0.6209 - val_loss: 0.9290
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7576 - loss: 0.6753 - val_accuracy: 0.6703 - val_loss: 0.8269
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7455 - loss: 0.6323 - val_accuracy: 0.6264 - val_loss: 0.8790
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7440 - loss: 0.6632 - val_accuracy: 0.7143 - val_loss: 0.7814
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8151 - loss: 0.5806 - val_accuracy: 0.6374 - val_loss: 0.8851
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7816 - loss: 0.5629 - val_accuracy: 0.6923 - val_loss: 0.7689
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8384 - loss: 0.4900 - val_accuracy: 0.6923 - val_loss: 0.7968
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8182 - loss: 0.4803 - val_accuracy: 0.7088 - val_loss: 0.7842
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8103 - loss: 0.5049 - val_accuracy: 0.7363 - val_loss: 0.7326
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.8611 - loss: 0.4428 - val_accuracy: 0.7253 - val_loss: 0.7674
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject19
# Accuracy     : 0.7253
# Precision    : 0.7409
# Recall       : 0.7253
# F1 Score     : 0.6901
# Specificity  : 0.8001
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.4801 - loss: 1.2359 - val_accuracy: 0.5847 - val_loss: 1.0636
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.5615 - loss: 1.0605 - val_accuracy: 0.5902 - val_loss: 0.9837
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.6201 - loss: 0.9522 - val_accuracy: 0.5956 - val_loss: 0.9810
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.5869 - loss: 0.9759 - val_accuracy: 0.5956 - val_loss: 0.9578
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6138 - loss: 0.9156 - val_accuracy: 0.6339 - val_loss: 0.9375
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.6842 - loss: 0.8113 - val_accuracy: 0.6448 - val_loss: 0.9078
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.7052 - loss: 0.8069 - val_accuracy: 0.6230 - val_loss: 0.8697
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.7143 - loss: 0.7364 - val_accuracy: 0.6448 - val_loss: 0.8159
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7325 - loss: 0.7014 - val_accuracy: 0.6831 - val_loss: 0.8034
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7135 - loss: 0.6764 - val_accuracy: 0.7049 - val_loss: 0.7629
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7701 - loss: 0.6200 - val_accuracy: 0.7158 - val_loss: 0.7260
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7816 - loss: 0.5588 - val_accuracy: 0.7213 - val_loss: 0.7210
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7725 - loss: 0.5548 - val_accuracy: 0.7104 - val_loss: 0.6826
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7920 - loss: 0.5201 - val_accuracy: 0.7268 - val_loss: 0.6729
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.7766 - loss: 0.5533 - val_accuracy: 0.7486 - val_loss: 0.6683
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8237 - loss: 0.4801 - val_accuracy: 0.7705 - val_loss: 0.6588
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8317 - loss: 0.4559 - val_accuracy: 0.7486 - val_loss: 0.6408
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8425 - loss: 0.4126 - val_accuracy: 0.7541 - val_loss: 0.6123
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8634 - loss: 0.3993 - val_accuracy: 0.7596 - val_loss: 0.6667
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - accuracy: 0.8695 - loss: 0.3655 - val_accuracy: 0.7650 - val_loss: 0.6001
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject2
# Accuracy     : 0.7650
# Precision    : 0.7649
# Recall       : 0.7650
# F1 Score     : 0.7488
# Specificity  : 0.8534
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 0.4553 - loss: 1.2368 - val_accuracy: 0.4955 - val_loss: 1.1297
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.4932 - loss: 1.1462 - val_accuracy: 0.5000 - val_loss: 1.0687
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.5380 - loss: 1.0575 - val_accuracy: 0.5227 - val_loss: 1.0092
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.5677 - loss: 1.0020 - val_accuracy: 0.6045 - val_loss: 0.9159
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6105 - loss: 0.9205 - val_accuracy: 0.6682 - val_loss: 0.8671
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.6300 - loss: 0.8731 - val_accuracy: 0.6682 - val_loss: 0.7754
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.7006 - loss: 0.7598 - val_accuracy: 0.6500 - val_loss: 0.7272
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7406 - loss: 0.6615 - val_accuracy: 0.6727 - val_loss: 0.6971
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7599 - loss: 0.6653 - val_accuracy: 0.7273 - val_loss: 0.6190
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7171 - loss: 0.6323 - val_accuracy: 0.7955 - val_loss: 0.5694
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.7980 - loss: 0.5610 - val_accuracy: 0.8045 - val_loss: 0.5290
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8132 - loss: 0.4903 - val_accuracy: 0.8136 - val_loss: 0.5153
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8178 - loss: 0.4670 - val_accuracy: 0.7591 - val_loss: 0.5249
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8146 - loss: 0.4626 - val_accuracy: 0.7773 - val_loss: 0.5137
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8700 - loss: 0.4067 - val_accuracy: 0.8318 - val_loss: 0.4590
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8434 - loss: 0.4198 - val_accuracy: 0.8409 - val_loss: 0.4556
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8511 - loss: 0.3891 - val_accuracy: 0.8500 - val_loss: 0.4464
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.8815 - loss: 0.3375 - val_accuracy: 0.8318 - val_loss: 0.4571
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8875 - loss: 0.3297 - val_accuracy: 0.8409 - val_loss: 0.4338
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8889 - loss: 0.3400 - val_accuracy: 0.8455 - val_loss: 0.4208
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Subject Subject20
# Accuracy     : 0.8455
# Precision    : 0.8546
# Recall       : 0.8455
# F1 Score     : 0.8433
# Specificity  : 0.8977
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.5097 - loss: 1.2537 - val_accuracy: 0.5517 - val_loss: 1.1492
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - accuracy: 0.5293 - loss: 1.1664 - val_accuracy: 0.5517 - val_loss: 1.1137
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.5832 - loss: 1.0264 - val_accuracy: 0.5320 - val_loss: 1.0225
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5800 - loss: 1.0149 - val_accuracy: 0.5468 - val_loss: 0.9649
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6299 - loss: 0.9015 - val_accuracy: 0.6158 - val_loss: 0.9172
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.6610 - loss: 0.8575 - val_accuracy: 0.6847 - val_loss: 0.8567
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7158 - loss: 0.7692 - val_accuracy: 0.7094 - val_loss: 0.7676
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7331 - loss: 0.7081 - val_accuracy: 0.7537 - val_loss: 0.7014
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.7723 - loss: 0.6502 - val_accuracy: 0.7635 - val_loss: 0.6569
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7766 - loss: 0.5928 - val_accuracy: 0.7783 - val_loss: 0.6224
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7851 - loss: 0.5624 - val_accuracy: 0.7833 - val_loss: 0.5886
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8260 - loss: 0.5152 - val_accuracy: 0.7734 - val_loss: 0.5810
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7818 - loss: 0.5628 - val_accuracy: 0.7586 - val_loss: 0.5693
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.8190 - loss: 0.4788 - val_accuracy: 0.7389 - val_loss: 0.6093
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.8472 - loss: 0.4365 - val_accuracy: 0.7980 - val_loss: 0.5384
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8576 - loss: 0.4161 - val_accuracy: 0.7931 - val_loss: 0.5303
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8570 - loss: 0.3912 - val_accuracy: 0.6847 - val_loss: 0.6901
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8299 - loss: 0.4605 - val_accuracy: 0.7783 - val_loss: 0.5588
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8717 - loss: 0.3931 - val_accuracy: 0.7783 - val_loss: 0.5324
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8844 - loss: 0.3611 - val_accuracy: 0.7833 - val_loss: 0.5682
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Subject Subject3
# Accuracy     : 0.7833
# Precision    : 0.7866
# Recall       : 0.7833
# F1 Score     : 0.7632
# Specificity  : 0.7901
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - accuracy: 0.4856 - loss: 1.2306 - val_accuracy: 0.5750 - val_loss: 1.0942
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.5592 - loss: 1.0793 - val_accuracy: 0.6150 - val_loss: 1.0102
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.6245 - loss: 0.9858 - val_accuracy: 0.6100 - val_loss: 0.9697
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.6277 - loss: 0.9369 - val_accuracy: 0.6250 - val_loss: 0.9558
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6239 - loss: 0.9364 - val_accuracy: 0.6800 - val_loss: 0.8614
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6766 - loss: 0.7877 - val_accuracy: 0.6900 - val_loss: 0.7884
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7316 - loss: 0.7340 - val_accuracy: 0.7250 - val_loss: 0.7219
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.7810 - loss: 0.6278 - val_accuracy: 0.7500 - val_loss: 0.6773
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7585 - loss: 0.6226 - val_accuracy: 0.7600 - val_loss: 0.6273
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.7821 - loss: 0.5721 - val_accuracy: 0.7600 - val_loss: 0.6108
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.7895 - loss: 0.5191 - val_accuracy: 0.7500 - val_loss: 0.6081
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.8297 - loss: 0.4579 - val_accuracy: 0.7950 - val_loss: 0.5960
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8228 - loss: 0.4418 - val_accuracy: 0.7900 - val_loss: 0.5519
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.8154 - loss: 0.4650 - val_accuracy: 0.7950 - val_loss: 0.5326
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8578 - loss: 0.4020 - val_accuracy: 0.8000 - val_loss: 0.5665
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8930 - loss: 0.3497 - val_accuracy: 0.8150 - val_loss: 0.5327
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8616 - loss: 0.3856 - val_accuracy: 0.8050 - val_loss: 0.5139
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8864 - loss: 0.3456 - val_accuracy: 0.8100 - val_loss: 0.5408
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8942 - loss: 0.3137 - val_accuracy: 0.8150 - val_loss: 0.5266
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.9141 - loss: 0.2650 - val_accuracy: 0.8300 - val_loss: 0.4871
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Subject Subject4
# Accuracy     : 0.8300
# Precision    : 0.8262
# Recall       : 0.8300
# F1 Score     : 0.8241
# Specificity  : 0.8899
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.3956 - loss: 1.3280 - val_accuracy: 0.5101 - val_loss: 1.1208
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.5343 - loss: 1.1278 - val_accuracy: 0.6010 - val_loss: 1.0288
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.5462 - loss: 1.0666 - val_accuracy: 0.6162 - val_loss: 0.9604
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.6023 - loss: 0.9809 - val_accuracy: 0.6263 - val_loss: 0.8964
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.6593 - loss: 0.9116 - val_accuracy: 0.6010 - val_loss: 0.8801
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.6799 - loss: 0.8410 - val_accuracy: 0.6919 - val_loss: 0.7768
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7278 - loss: 0.7539 - val_accuracy: 0.7020 - val_loss: 0.7421
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7290 - loss: 0.6973 - val_accuracy: 0.7323 - val_loss: 0.6871
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7587 - loss: 0.6348 - val_accuracy: 0.7172 - val_loss: 0.6659
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7726 - loss: 0.6321 - val_accuracy: 0.7626 - val_loss: 0.6495
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8018 - loss: 0.5789 - val_accuracy: 0.7626 - val_loss: 0.6078
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.7557 - loss: 0.6018 - val_accuracy: 0.7626 - val_loss: 0.5909
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8090 - loss: 0.5428 - val_accuracy: 0.7727 - val_loss: 0.5752
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8052 - loss: 0.5079 - val_accuracy: 0.7778 - val_loss: 0.5517
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8321 - loss: 0.4501 - val_accuracy: 0.7828 - val_loss: 0.5549
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8184 - loss: 0.4358 - val_accuracy: 0.7727 - val_loss: 0.5610
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.8606 - loss: 0.3940 - val_accuracy: 0.7677 - val_loss: 0.5506
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8765 - loss: 0.3821 - val_accuracy: 0.8030 - val_loss: 0.5121
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8714 - loss: 0.3437 - val_accuracy: 0.8131 - val_loss: 0.4854
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8746 - loss: 0.3594 - val_accuracy: 0.7879 - val_loss: 0.4965
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Subject Subject5
# Accuracy     : 0.7879
# Precision    : 0.7820
# Recall       : 0.7879
# F1 Score     : 0.7604
# Specificity  : 0.8485
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 0.4382 - loss: 1.2717 - val_accuracy: 0.5220 - val_loss: 1.2263
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.5225 - loss: 1.1961 - val_accuracy: 0.5220 - val_loss: 1.2056
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.5492 - loss: 1.1518 - val_accuracy: 0.5055 - val_loss: 1.1751
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.5541 - loss: 1.1078 - val_accuracy: 0.5440 - val_loss: 1.1545
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.5545 - loss: 1.0898 - val_accuracy: 0.5385 - val_loss: 1.1196
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.6216 - loss: 0.9648 - val_accuracy: 0.5275 - val_loss: 1.0539
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.6797 - loss: 0.9030 - val_accuracy: 0.6209 - val_loss: 0.9993
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6585 - loss: 0.8776 - val_accuracy: 0.6264 - val_loss: 0.9389
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.6506 - loss: 0.8563 - val_accuracy: 0.5714 - val_loss: 0.9705
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.6670 - loss: 0.8003 - val_accuracy: 0.6209 - val_loss: 0.8836
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7023 - loss: 0.7124 - val_accuracy: 0.6703 - val_loss: 0.8749
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.7735 - loss: 0.6608 - val_accuracy: 0.6264 - val_loss: 0.8442
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7743 - loss: 0.6135 - val_accuracy: 0.6484 - val_loss: 0.8305
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7559 - loss: 0.6019 - val_accuracy: 0.6484 - val_loss: 0.8360
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7597 - loss: 0.6047 - val_accuracy: 0.6648 - val_loss: 0.8089
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.7704 - loss: 0.5579 - val_accuracy: 0.6648 - val_loss: 0.8010
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8361 - loss: 0.4905 - val_accuracy: 0.6429 - val_loss: 0.8402
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7879 - loss: 0.5444 - val_accuracy: 0.6703 - val_loss: 0.7880
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8488 - loss: 0.4338 - val_accuracy: 0.7308 - val_loss: 0.7690
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8380 - loss: 0.4610 - val_accuracy: 0.7088 - val_loss: 0.7644
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject6
# Accuracy     : 0.7088
# Precision    : 0.7086
# Recall       : 0.7088
# F1 Score     : 0.7069
# Specificity  : 0.8245
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.4608 - loss: 1.2794 - val_accuracy: 0.5249 - val_loss: 1.1695
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.5014 - loss: 1.1856 - val_accuracy: 0.5359 - val_loss: 1.1210
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.5449 - loss: 1.0994 - val_accuracy: 0.5304 - val_loss: 1.0858
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.5724 - loss: 1.0585 - val_accuracy: 0.5304 - val_loss: 1.0610
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.5969 - loss: 0.9938 - val_accuracy: 0.5967 - val_loss: 0.9957
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.6365 - loss: 0.9293 - val_accuracy: 0.6188 - val_loss: 0.9050
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.6894 - loss: 0.8197 - val_accuracy: 0.6906 - val_loss: 0.7857
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7771 - loss: 0.6797 - val_accuracy: 0.7403 - val_loss: 0.6743
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.8213 - loss: 0.5396 - val_accuracy: 0.7293 - val_loss: 0.6523
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8103 - loss: 0.5659 - val_accuracy: 0.8122 - val_loss: 0.5587
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8759 - loss: 0.4311 - val_accuracy: 0.8398 - val_loss: 0.5580
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9037 - loss: 0.4178 - val_accuracy: 0.8398 - val_loss: 0.5306
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8839 - loss: 0.3745 - val_accuracy: 0.8177 - val_loss: 0.5141
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8916 - loss: 0.3236 - val_accuracy: 0.8508 - val_loss: 0.5254
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8867 - loss: 0.3027 - val_accuracy: 0.8453 - val_loss: 0.5048
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.9183 - loss: 0.3310 - val_accuracy: 0.8398 - val_loss: 0.4732
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8915 - loss: 0.3251 - val_accuracy: 0.8453 - val_loss: 0.4821
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9086 - loss: 0.2736 - val_accuracy: 0.8508 - val_loss: 0.4403
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9043 - loss: 0.2819 - val_accuracy: 0.8619 - val_loss: 0.4575
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9423 - loss: 0.1997 - val_accuracy: 0.8508 - val_loss: 0.4665
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject7
# Accuracy     : 0.8508
# Precision    : 0.8590
# Recall       : 0.8508
# F1 Score     : 0.8514
# Specificity  : 0.9405
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.4987 - loss: 1.2191 - val_accuracy: 0.5220 - val_loss: 1.1703
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.5063 - loss: 1.1815 - val_accuracy: 0.5330 - val_loss: 1.1232
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.5465 - loss: 1.1008 - val_accuracy: 0.5330 - val_loss: 1.0919
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5894 - loss: 1.0248 - val_accuracy: 0.5549 - val_loss: 1.0553
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.6022 - loss: 0.9924 - val_accuracy: 0.5659 - val_loss: 1.0341
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.6193 - loss: 0.9504 - val_accuracy: 0.5714 - val_loss: 0.9875
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6880 - loss: 0.8241 - val_accuracy: 0.6099 - val_loss: 0.9317
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7015 - loss: 0.7675 - val_accuracy: 0.6374 - val_loss: 0.9095
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7435 - loss: 0.6961 - val_accuracy: 0.6703 - val_loss: 0.8797
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.7555 - loss: 0.6668 - val_accuracy: 0.6319 - val_loss: 0.9336
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7542 - loss: 0.6669 - val_accuracy: 0.6868 - val_loss: 0.8423
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7855 - loss: 0.5693 - val_accuracy: 0.6868 - val_loss: 0.8009
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - accuracy: 0.8020 - loss: 0.5635 - val_accuracy: 0.7033 - val_loss: 0.8266
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.7943 - loss: 0.5375 - val_accuracy: 0.6923 - val_loss: 0.7892
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8338 - loss: 0.4617 - val_accuracy: 0.6868 - val_loss: 0.8112
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.8408 - loss: 0.4372 - val_accuracy: 0.6978 - val_loss: 0.8194
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8359 - loss: 0.4446 - val_accuracy: 0.6978 - val_loss: 0.7842
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.8636 - loss: 0.4112 - val_accuracy: 0.6813 - val_loss: 0.7994
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.8733 - loss: 0.3684 - val_accuracy: 0.7088 - val_loss: 0.7842
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8752 - loss: 0.3412 - val_accuracy: 0.6978 - val_loss: 0.7950
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject8
# Accuracy     : 0.6978
# Precision    : 0.6920
# Recall       : 0.6978
# F1 Score     : 0.6920
# Specificity  : 0.8369
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.4791 - loss: 1.2814 - val_accuracy: 0.5220 - val_loss: 1.1095
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.5783 - loss: 1.0346 - val_accuracy: 0.5714 - val_loss: 1.0316
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.5875 - loss: 1.0130 - val_accuracy: 0.5549 - val_loss: 0.9836
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.6055 - loss: 0.9142 - val_accuracy: 0.5824 - val_loss: 0.9532
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.6507 - loss: 0.8588 - val_accuracy: 0.5934 - val_loss: 0.9187
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7138 - loss: 0.7743 - val_accuracy: 0.5989 - val_loss: 0.9203
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.6831 - loss: 0.7888 - val_accuracy: 0.6319 - val_loss: 0.9048
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7071 - loss: 0.7576 - val_accuracy: 0.6429 - val_loss: 0.8083
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7612 - loss: 0.6482 - val_accuracy: 0.6538 - val_loss: 0.7724
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7939 - loss: 0.5829 - val_accuracy: 0.6648 - val_loss: 0.7501
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7814 - loss: 0.5845 - val_accuracy: 0.6648 - val_loss: 0.7504
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.8463 - loss: 0.4918 - val_accuracy: 0.7143 - val_loss: 0.6892
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8351 - loss: 0.5141 - val_accuracy: 0.7308 - val_loss: 0.6592
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.8641 - loss: 0.4371 - val_accuracy: 0.7418 - val_loss: 0.6637
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 0.8745 - loss: 0.4066 - val_accuracy: 0.7637 - val_loss: 0.6460
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8868 - loss: 0.3400 - val_accuracy: 0.7473 - val_loss: 0.6373
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8988 - loss: 0.3255 - val_accuracy: 0.7857 - val_loss: 0.6032
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.8998 - loss: 0.3022 - val_accuracy: 0.7527 - val_loss: 0.6365
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9076 - loss: 0.3076 - val_accuracy: 0.7692 - val_loss: 0.5970
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9242 - loss: 0.2903 - val_accuracy: 0.7802 - val_loss: 0.6124
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Subject Subject9
# Accuracy     : 0.7802
# Precision    : 0.8019
# Recall       : 0.7802
# F1 Score     : 0.7853
# Specificity  : 0.9008
#
# === Summary Metrics ===
#
# === Per-Subject Metrics ===
# Average Per-Subject Accuracy: 0.7768597220296243
# Average Per-Subject Precision: 0.784206950900988
# Average Per-Subject Recall: 0.7768597220296243
# Average Per-Subject F1 Score: 0.7674225039285393
# Average Per-Subject Specificity: 0.8628565335005659

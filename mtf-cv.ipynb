# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cleaned/cleaned_dataset.csv

# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import pandas as pd
from pyts.image import MarkovTransitionField
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import warnings
from collections import Counter
import gc
from tensorflow.keras import backend as K

warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/kaggle/input/cleaned/cleaned_dataset.csv')  # Replace with your path
df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.sort_values(['SubjectID', 'DateTime'])

# Preprocess features
feature_cols = ['AccX', 'AccY', 'AccZ', 'Temp', 'EDA', 'HeartRate', 'SpO2']
target_col = 'Label'

scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

def create_windows(df, feature_cols, target_col, window_size=100, step=20):
    X = []
    y = []
    for subject_id, subject_df in df.groupby('SubjectID'):
        subject_data = subject_df.reset_index(drop=True)
        features = subject_data[feature_cols].values
        labels = subject_data[target_col].values
        for start in range(0, len(features) - window_size, step):
            end = start + window_size
            window_x = features[start:end]
            window_y = labels[start:end]
            label = Counter(window_y).most_common(1)[0][0]
            X.append(window_x)
            y.append(label)
    return np.array(X), np.array(y)

X, y = create_windows(df, feature_cols, target_col)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

# Convert time-series to images using MTF
def time_series_to_image_mtf(sample, image_size=64):
    mtf = MarkovTransitionField(image_size=image_size)
    img_list = []
    for i in range(sample.shape[1]):
        ts = sample[:, i]
        img = mtf.fit_transform(ts.reshape(1, -1))[0]
        img_list.append(img)
    img = np.stack(img_list, axis=-1)
    return img

image_data = np.array([time_series_to_image_mtf(seq) for seq in X])

# CNN model
def build_image_model(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Evaluation
def evaluate_model(model, X_test, y_test, label_encoder, title="Model"):
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true_classes, y_pred_classes)
    precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
    recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
    f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    specificity_per_class = []
    for i in range(len(cm)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(np.delete(cm, i, axis=0)[:, i])
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        specificity_per_class.append(specificity)
    weighted_specificity = np.average(specificity_per_class, weights=np.bincount(y_true_classes))

    print(f"\n{title}")
    print(f"Accuracy     : {accuracy:.4f}")
    print(f"Precision    : {precision:.4f}")
    print(f"Recall       : {recall:.4f}")
    print(f"F1 Score     : {f1:.4f}")
    print(f"Specificity  : {weighted_specificity:.4f}")

    return accuracy, precision, recall, f1, weighted_specificity

# Intra-Subject Classification: Ensure data consistency for splitting
results_subjectwise = {}
for subject_id, subject_df in df.groupby('SubjectID'):
    X_subject, y_subject = create_windows(subject_df, feature_cols, target_col)
    
    # Convert time-series data to images for subject-wise classification
    image_data_subject = np.array([time_series_to_image_mtf(seq) for seq in X_subject])
    
    # Ensure labels and features have the same length for splitting
    y_subject_encoded = le.transform(y_subject)
    
    X_train_subj, X_test_subj, y_train_subj, y_test_subj = train_test_split(
        image_data_subject, to_categorical(y_subject_encoded), test_size=0.2, stratify=y_subject_encoded, random_state=42
    )
    
    img_model_subj = build_image_model(X_train_subj.shape[1:], y_cat.shape[1])
    img_model_subj.fit(X_train_subj, y_train_subj, validation_data=(X_test_subj, y_test_subj),
                       epochs=20, batch_size=32)
    
    # Evaluate
    acc, precision, recall, f1, specificity = evaluate_model(img_model_subj, X_test_subj, y_test_subj, le, title=f"Subject {subject_id}")
    results_subjectwise[subject_id] = {'Accuracy': acc, 'Precision': precision, 'Recall': recall, 'F1': f1, 'Specificity': specificity}
    
    # Save model
    model_filename = f"/kaggle/working/subject_{subject_id}_cnn_model.h5"
    img_model_subj.save(model_filename)
    print(f"Model for Subject {subject_id} saved as {model_filename}")
# === Summary ===

print("\n=== Summary Metrics ===")

# Average Per-Subject Metrics
print("\n=== Per-Subject Metrics ===")
print("Average Per-Subject Accuracy:", np.mean([result['Accuracy'] for result in results_subjectwise.values()]))
print("Average Per-Subject Precision:", np.mean([result['Precision'] for result in results_subjectwise.values()]))
print("Average Per-Subject Recall:", np.mean([result['Recall'] for result in results_subjectwise.values()]))
print("Average Per-Subject F1 Score:", np.mean([result['F1'] for result in results_subjectwise.values()]))
print("Average Per-Subject Specificity:", np.mean([result['Specificity'] for result in results_subjectwise.values()]))

# Save Intra-Subject Results
with open("intra_subject_results.txt", "w") as f:
    f.write("=== Intra-Subject Evaluation Results ===\n\n")
    for subject_id, metrics in results_subjectwise.items():
        f.write(f"Subject {subject_id}:\n")
        for metric_name, metric_value in metrics.items():
            f.write(f"  {metric_name}: {metric_value:.4f}\n")
        f.write("\n")

    f.write("=== Average Intra-Subject Metrics ===\n")
    f.write(f"Accuracy     : {np.mean([res['Accuracy'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Precision    : {np.mean([res['Precision'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Recall       : {np.mean([res['Recall'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"F1 Score     : {np.mean([res['F1'] for res in results_subjectwise.values()]):.4f}\n")
    f.write(f"Specificity  : {np.mean([res['Specificity'] for res in results_subjectwise.values()]):.4f}\n")
# Out:
# 2025-04-14 11:46:35.882349: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744631196.140358      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744631196.223422      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-14 11:48:56.947597: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.4926 - loss: 1.2178 - val_accuracy: 0.5381 - val_loss: 0.9942
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.6205 - loss: 0.9363 - val_accuracy: 0.6853 - val_loss: 0.8528
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6708 - loss: 0.8437 - val_accuracy: 0.7310 - val_loss: 0.7720
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.6991 - loss: 0.8076 - val_accuracy: 0.6954 - val_loss: 0.7088
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7093 - loss: 0.7296 - val_accuracy: 0.7766 - val_loss: 0.6235
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7094 - loss: 0.6818 - val_accuracy: 0.7259 - val_loss: 0.6124
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7500 - loss: 0.6086 - val_accuracy: 0.8173 - val_loss: 0.5759
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7400 - loss: 0.6138 - val_accuracy: 0.7817 - val_loss: 0.5645
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7472 - loss: 0.6024 - val_accuracy: 0.7919 - val_loss: 0.5063
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7887 - loss: 0.5265 - val_accuracy: 0.8325 - val_loss: 0.4732
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7988 - loss: 0.5190 - val_accuracy: 0.8325 - val_loss: 0.4605
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7831 - loss: 0.5107 - val_accuracy: 0.8223 - val_loss: 0.4647
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7952 - loss: 0.5230 - val_accuracy: 0.8223 - val_loss: 0.4429
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.8248 - loss: 0.4949 - val_accuracy: 0.8477 - val_loss: 0.4094
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8387 - loss: 0.4519 - val_accuracy: 0.8426 - val_loss: 0.4028
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8286 - loss: 0.4365 - val_accuracy: 0.8680 - val_loss: 0.3676
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.8550 - loss: 0.3833 - val_accuracy: 0.8528 - val_loss: 0.3770
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.8410 - loss: 0.3731 - val_accuracy: 0.8680 - val_loss: 0.3767
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8348 - loss: 0.3884 - val_accuracy: 0.8629 - val_loss: 0.3499
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8683 - loss: 0.3404 - val_accuracy: 0.8325 - val_loss: 0.4342
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Subject Subject1
# Accuracy     : 0.8325
# Precision    : 0.8513
# Recall       : 0.8325
# F1 Score     : 0.8295
# Specificity  : 0.9315
# Model for Subject Subject1 saved as /kaggle/working/subject_Subject1_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.5220 - loss: 1.1232 - val_accuracy: 0.6813 - val_loss: 0.8076
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7459 - loss: 0.7208 - val_accuracy: 0.7088 - val_loss: 0.6810
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.7388 - loss: 0.6977 - val_accuracy: 0.7143 - val_loss: 0.6748
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7224 - loss: 0.6832 - val_accuracy: 0.7857 - val_loss: 0.6188
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7770 - loss: 0.5724 - val_accuracy: 0.7857 - val_loss: 0.5728
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7860 - loss: 0.5761 - val_accuracy: 0.7582 - val_loss: 0.5563
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7895 - loss: 0.5641 - val_accuracy: 0.7802 - val_loss: 0.5384
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8198 - loss: 0.5129 - val_accuracy: 0.8077 - val_loss: 0.5304
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7981 - loss: 0.5334 - val_accuracy: 0.8297 - val_loss: 0.4804
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8281 - loss: 0.4525 - val_accuracy: 0.8297 - val_loss: 0.4651
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8386 - loss: 0.4443 - val_accuracy: 0.7912 - val_loss: 0.4727
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8442 - loss: 0.4520 - val_accuracy: 0.8297 - val_loss: 0.4493
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.8547 - loss: 0.4316 - val_accuracy: 0.8187 - val_loss: 0.4498
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.8577 - loss: 0.4039 - val_accuracy: 0.8132 - val_loss: 0.4583
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8511 - loss: 0.4339 - val_accuracy: 0.7967 - val_loss: 0.4699
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8635 - loss: 0.4161 - val_accuracy: 0.8516 - val_loss: 0.4254
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8816 - loss: 0.3652 - val_accuracy: 0.8352 - val_loss: 0.4589
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8579 - loss: 0.3817 - val_accuracy: 0.8407 - val_loss: 0.4199
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.8982 - loss: 0.3121 - val_accuracy: 0.8462 - val_loss: 0.4126
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8746 - loss: 0.3219 - val_accuracy: 0.8407 - val_loss: 0.3749
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject10
# Accuracy     : 0.8407
# Precision    : 0.8383
# Recall       : 0.8407
# F1 Score     : 0.8385
# Specificity  : 0.9091
# Model for Subject Subject10 saved as /kaggle/working/subject_Subject10_cnn_model.h5
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.4976 - loss: 1.2195 - val_accuracy: 0.5482 - val_loss: 1.0459
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.6075 - loss: 1.0085 - val_accuracy: 0.6754 - val_loss: 0.8375
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.6499 - loss: 0.8716 - val_accuracy: 0.7018 - val_loss: 0.7531
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.6752 - loss: 0.7537 - val_accuracy: 0.6886 - val_loss: 0.7050
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.6748 - loss: 0.7505 - val_accuracy: 0.7018 - val_loss: 0.7066
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7224 - loss: 0.6586 - val_accuracy: 0.7237 - val_loss: 0.6496
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.7234 - loss: 0.5961 - val_accuracy: 0.6974 - val_loss: 0.6585
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7470 - loss: 0.6125 - val_accuracy: 0.7412 - val_loss: 0.6110
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.7456 - loss: 0.5982 - val_accuracy: 0.7237 - val_loss: 0.6407
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.7473 - loss: 0.5801 - val_accuracy: 0.7675 - val_loss: 0.6075
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7590 - loss: 0.5878 - val_accuracy: 0.7588 - val_loss: 0.5915
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.7477 - loss: 0.5745 - val_accuracy: 0.7632 - val_loss: 0.5824
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.7880 - loss: 0.5136 - val_accuracy: 0.7807 - val_loss: 0.5782
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 179ms/step - accuracy: 0.7713 - loss: 0.4975 - val_accuracy: 0.7588 - val_loss: 0.6006
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7731 - loss: 0.5133 - val_accuracy: 0.7763 - val_loss: 0.5879
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 179ms/step - accuracy: 0.7782 - loss: 0.4855 - val_accuracy: 0.7632 - val_loss: 0.5453
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7794 - loss: 0.4887 - val_accuracy: 0.7719 - val_loss: 0.5688
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.8243 - loss: 0.4518 - val_accuracy: 0.7851 - val_loss: 0.5395
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.7924 - loss: 0.4653 - val_accuracy: 0.7982 - val_loss: 0.5124
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8146 - loss: 0.4556 - val_accuracy: 0.7851 - val_loss: 0.5572
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Subject Subject11
# Accuracy     : 0.7851
# Precision    : 0.7831
# Recall       : 0.7851
# F1 Score     : 0.7775
# Specificity  : 0.8514
# Model for Subject Subject11 saved as /kaggle/working/subject_Subject11_cnn_model.h5
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - accuracy: 0.4876 - loss: 1.1957 - val_accuracy: 0.6378 - val_loss: 0.9053
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6518 - loss: 0.8883 - val_accuracy: 0.7027 - val_loss: 0.7974
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7229 - loss: 0.7274 - val_accuracy: 0.7027 - val_loss: 0.7013
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7141 - loss: 0.6752 - val_accuracy: 0.7405 - val_loss: 0.6761
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7692 - loss: 0.6006 - val_accuracy: 0.7459 - val_loss: 0.6143
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7726 - loss: 0.5814 - val_accuracy: 0.7459 - val_loss: 0.5755
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.7712 - loss: 0.5468 - val_accuracy: 0.7514 - val_loss: 0.5556
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7886 - loss: 0.5205 - val_accuracy: 0.7622 - val_loss: 0.6126
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7811 - loss: 0.5031 - val_accuracy: 0.7568 - val_loss: 0.5556
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.7877 - loss: 0.5088 - val_accuracy: 0.7622 - val_loss: 0.5270
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8249 - loss: 0.4858 - val_accuracy: 0.7676 - val_loss: 0.5385
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7948 - loss: 0.4920 - val_accuracy: 0.8108 - val_loss: 0.4943
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8165 - loss: 0.4543 - val_accuracy: 0.7946 - val_loss: 0.4996
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8260 - loss: 0.4327 - val_accuracy: 0.7730 - val_loss: 0.4855
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8295 - loss: 0.4264 - val_accuracy: 0.7946 - val_loss: 0.4718
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8718 - loss: 0.3446 - val_accuracy: 0.8000 - val_loss: 0.4626
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8300 - loss: 0.4066 - val_accuracy: 0.8000 - val_loss: 0.4888
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.8460 - loss: 0.3566 - val_accuracy: 0.8000 - val_loss: 0.5272
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8376 - loss: 0.4136 - val_accuracy: 0.8270 - val_loss: 0.4435
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8349 - loss: 0.3923 - val_accuracy: 0.8324 - val_loss: 0.4295
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Subject Subject12
# Accuracy     : 0.8324
# Precision    : 0.8320
# Recall       : 0.8324
# F1 Score     : 0.8304
# Specificity  : 0.9129
# Model for Subject Subject12 saved as /kaggle/working/subject_Subject12_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - accuracy: 0.4667 - loss: 1.2067 - val_accuracy: 0.6264 - val_loss: 0.9350
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6605 - loss: 0.8800 - val_accuracy: 0.6758 - val_loss: 0.8049
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7149 - loss: 0.7656 - val_accuracy: 0.7308 - val_loss: 0.7520
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.7469 - loss: 0.6858 - val_accuracy: 0.7418 - val_loss: 0.6976
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7621 - loss: 0.6639 - val_accuracy: 0.7747 - val_loss: 0.6560
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7765 - loss: 0.5957 - val_accuracy: 0.7857 - val_loss: 0.6174
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8086 - loss: 0.5527 - val_accuracy: 0.8022 - val_loss: 0.5854
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7877 - loss: 0.5550 - val_accuracy: 0.8187 - val_loss: 0.5552
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8287 - loss: 0.4997 - val_accuracy: 0.8187 - val_loss: 0.5373
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8431 - loss: 0.4608 - val_accuracy: 0.8187 - val_loss: 0.5103
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8383 - loss: 0.4266 - val_accuracy: 0.7802 - val_loss: 0.5032
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.8706 - loss: 0.3976 - val_accuracy: 0.8077 - val_loss: 0.4763
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8270 - loss: 0.4306 - val_accuracy: 0.8187 - val_loss: 0.4863
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8407 - loss: 0.4341 - val_accuracy: 0.8187 - val_loss: 0.4555
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.8892 - loss: 0.3774 - val_accuracy: 0.8242 - val_loss: 0.4576
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8724 - loss: 0.3416 - val_accuracy: 0.8352 - val_loss: 0.4221
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8452 - loss: 0.3997 - val_accuracy: 0.8077 - val_loss: 0.4309
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8775 - loss: 0.3413 - val_accuracy: 0.8132 - val_loss: 0.4477
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8892 - loss: 0.3095 - val_accuracy: 0.8352 - val_loss: 0.4118
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.8889 - loss: 0.3155 - val_accuracy: 0.8626 - val_loss: 0.3807
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Subject Subject13
# Accuracy     : 0.8626
# Precision    : 0.8670
# Recall       : 0.8626
# F1 Score     : 0.8633
# Specificity  : 0.9338
# Model for Subject Subject13 saved as /kaggle/working/subject_Subject13_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - accuracy: 0.4782 - loss: 1.2211 - val_accuracy: 0.6044 - val_loss: 0.9406
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6480 - loss: 0.8661 - val_accuracy: 0.7582 - val_loss: 0.6831
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7421 - loss: 0.6581 - val_accuracy: 0.8022 - val_loss: 0.5856
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7876 - loss: 0.5780 - val_accuracy: 0.8462 - val_loss: 0.5337
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8099 - loss: 0.5266 - val_accuracy: 0.8022 - val_loss: 0.5718
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.8219 - loss: 0.5058 - val_accuracy: 0.8462 - val_loss: 0.4832
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8232 - loss: 0.4741 - val_accuracy: 0.8571 - val_loss: 0.4536
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8376 - loss: 0.4499 - val_accuracy: 0.8407 - val_loss: 0.4675
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8400 - loss: 0.4821 - val_accuracy: 0.8681 - val_loss: 0.4146
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8298 - loss: 0.3936 - val_accuracy: 0.8736 - val_loss: 0.4084
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.8822 - loss: 0.3354 - val_accuracy: 0.8626 - val_loss: 0.3827
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8794 - loss: 0.3239 - val_accuracy: 0.8846 - val_loss: 0.3675
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8850 - loss: 0.3123 - val_accuracy: 0.8956 - val_loss: 0.3719
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8963 - loss: 0.2884 - val_accuracy: 0.8901 - val_loss: 0.3461
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9049 - loss: 0.3014 - val_accuracy: 0.8901 - val_loss: 0.3294
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9129 - loss: 0.2544 - val_accuracy: 0.8846 - val_loss: 0.3289
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8956 - loss: 0.2602 - val_accuracy: 0.8956 - val_loss: 0.3319
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.9145 - loss: 0.2502 - val_accuracy: 0.8626 - val_loss: 0.3617
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.9184 - loss: 0.2269 - val_accuracy: 0.8956 - val_loss: 0.3071
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.9329 - loss: 0.1951 - val_accuracy: 0.8956 - val_loss: 0.3131
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Subject Subject14
# Accuracy     : 0.8956
# Precision    : 0.8949
# Recall       : 0.8956
# F1 Score     : 0.8949
# Specificity  : 0.9399
# Model for Subject Subject14 saved as /kaggle/working/subject_Subject14_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.5274 - loss: 1.1920 - val_accuracy: 0.5525 - val_loss: 1.0628
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.5885 - loss: 1.0168 - val_accuracy: 0.6354 - val_loss: 0.9184
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6555 - loss: 0.8402 - val_accuracy: 0.6519 - val_loss: 0.8150
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.7056 - loss: 0.7338 - val_accuracy: 0.6796 - val_loss: 0.7392
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7433 - loss: 0.6512 - val_accuracy: 0.7182 - val_loss: 0.6691
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7638 - loss: 0.6046 - val_accuracy: 0.7569 - val_loss: 0.6363
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7822 - loss: 0.5215 - val_accuracy: 0.7293 - val_loss: 0.5545
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 191ms/step - accuracy: 0.7973 - loss: 0.5461 - val_accuracy: 0.7790 - val_loss: 0.5345
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8569 - loss: 0.4440 - val_accuracy: 0.7845 - val_loss: 0.4894
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8378 - loss: 0.4252 - val_accuracy: 0.7845 - val_loss: 0.4700
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8566 - loss: 0.4362 - val_accuracy: 0.7569 - val_loss: 0.5406
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8232 - loss: 0.4578 - val_accuracy: 0.8011 - val_loss: 0.4518
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8427 - loss: 0.4042 - val_accuracy: 0.8011 - val_loss: 0.5045
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8844 - loss: 0.3358 - val_accuracy: 0.8287 - val_loss: 0.4416
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.8717 - loss: 0.3778 - val_accuracy: 0.8011 - val_loss: 0.4563
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8795 - loss: 0.3379 - val_accuracy: 0.8122 - val_loss: 0.4821
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8928 - loss: 0.2844 - val_accuracy: 0.8564 - val_loss: 0.4178
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8932 - loss: 0.3256 - val_accuracy: 0.7845 - val_loss: 0.4266
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8925 - loss: 0.2942 - val_accuracy: 0.8287 - val_loss: 0.3972
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.9156 - loss: 0.2341 - val_accuracy: 0.8398 - val_loss: 0.3774
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#
# Subject Subject15
# Accuracy     : 0.8398
# Precision    : 0.8419
# Recall       : 0.8398
# F1 Score     : 0.8277
# Specificity  : 0.8837
# Model for Subject Subject15 saved as /kaggle/working/subject_Subject15_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - accuracy: 0.4959 - loss: 1.2103 - val_accuracy: 0.6175 - val_loss: 0.9721
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.6367 - loss: 0.8974 - val_accuracy: 0.6721 - val_loss: 0.8077
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6916 - loss: 0.7793 - val_accuracy: 0.6940 - val_loss: 0.7672
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7211 - loss: 0.7474 - val_accuracy: 0.7213 - val_loss: 0.6997
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7609 - loss: 0.6786 - val_accuracy: 0.7486 - val_loss: 0.6742
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7812 - loss: 0.5809 - val_accuracy: 0.7541 - val_loss: 0.6406
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7912 - loss: 0.5714 - val_accuracy: 0.7541 - val_loss: 0.6332
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7956 - loss: 0.5485 - val_accuracy: 0.7486 - val_loss: 0.6198
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.8272 - loss: 0.4761 - val_accuracy: 0.7705 - val_loss: 0.5806
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.8196 - loss: 0.4966 - val_accuracy: 0.7923 - val_loss: 0.5708
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.8124 - loss: 0.4765 - val_accuracy: 0.7923 - val_loss: 0.5526
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7991 - loss: 0.4841 - val_accuracy: 0.7705 - val_loss: 0.5509
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8580 - loss: 0.3941 - val_accuracy: 0.7814 - val_loss: 0.5502
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8270 - loss: 0.4117 - val_accuracy: 0.8142 - val_loss: 0.5068
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8696 - loss: 0.3486 - val_accuracy: 0.7650 - val_loss: 0.5468
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8538 - loss: 0.4032 - val_accuracy: 0.8142 - val_loss: 0.4693
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.8348 - loss: 0.3952 - val_accuracy: 0.8087 - val_loss: 0.4624
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8716 - loss: 0.3322 - val_accuracy: 0.8142 - val_loss: 0.4612
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.9009 - loss: 0.2807 - val_accuracy: 0.8251 - val_loss: 0.4690
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8729 - loss: 0.3483 - val_accuracy: 0.8361 - val_loss: 0.4347
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Subject Subject16
# Accuracy     : 0.8361
# Precision    : 0.8282
# Recall       : 0.8361
# F1 Score     : 0.8268
# Specificity  : 0.9077
# Model for Subject Subject16 saved as /kaggle/working/subject_Subject16_cnn_model.h5
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.4755 - loss: 1.2507 - val_accuracy: 0.6127 - val_loss: 1.0971
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.5724 - loss: 1.1136 - val_accuracy: 0.6324 - val_loss: 1.0006
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.6072 - loss: 1.0083 - val_accuracy: 0.6275 - val_loss: 0.9706
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6124 - loss: 1.0005 - val_accuracy: 0.6176 - val_loss: 0.9415
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6128 - loss: 0.9413 - val_accuracy: 0.6275 - val_loss: 0.9262
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.6056 - loss: 0.9250 - val_accuracy: 0.6275 - val_loss: 0.9048
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6261 - loss: 0.9023 - val_accuracy: 0.6275 - val_loss: 0.8983
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6485 - loss: 0.8345 - val_accuracy: 0.6078 - val_loss: 0.8655
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6625 - loss: 0.8530 - val_accuracy: 0.6127 - val_loss: 0.8649
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.6529 - loss: 0.7978 - val_accuracy: 0.6127 - val_loss: 0.8664
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6368 - loss: 0.8025 - val_accuracy: 0.6225 - val_loss: 0.9052
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6768 - loss: 0.7703 - val_accuracy: 0.6324 - val_loss: 0.8474
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6723 - loss: 0.7848 - val_accuracy: 0.6422 - val_loss: 0.8771
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.6659 - loss: 0.7481 - val_accuracy: 0.5882 - val_loss: 0.8207
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6981 - loss: 0.7122 - val_accuracy: 0.6275 - val_loss: 0.8301
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7164 - loss: 0.6600 - val_accuracy: 0.6520 - val_loss: 0.8162
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.6870 - loss: 0.6608 - val_accuracy: 0.6373 - val_loss: 0.7992
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7445 - loss: 0.6270 - val_accuracy: 0.6471 - val_loss: 0.7976
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7406 - loss: 0.6089 - val_accuracy: 0.6471 - val_loss: 0.7778
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7467 - loss: 0.5826 - val_accuracy: 0.6422 - val_loss: 0.7933
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject17
# Accuracy     : 0.6422
# Precision    : 0.6148
# Recall       : 0.6422
# F1 Score     : 0.5843
# Specificity  : 0.7046
# Model for Subject Subject17 saved as /kaggle/working/subject_Subject17_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - accuracy: 0.4883 - loss: 1.1844 - val_accuracy: 0.6319 - val_loss: 0.9265
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.6197 - loss: 0.9171 - val_accuracy: 0.6593 - val_loss: 0.7995
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.6589 - loss: 0.8115 - val_accuracy: 0.7143 - val_loss: 0.7561
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7194 - loss: 0.6891 - val_accuracy: 0.7418 - val_loss: 0.7189
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7315 - loss: 0.6817 - val_accuracy: 0.7637 - val_loss: 0.6817
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7517 - loss: 0.6134 - val_accuracy: 0.7527 - val_loss: 0.6944
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7388 - loss: 0.6578 - val_accuracy: 0.7088 - val_loss: 0.6586
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7838 - loss: 0.5211 - val_accuracy: 0.7473 - val_loss: 0.6544
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7652 - loss: 0.5721 - val_accuracy: 0.7747 - val_loss: 0.5917
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8134 - loss: 0.4766 - val_accuracy: 0.7692 - val_loss: 0.6067
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.8133 - loss: 0.4923 - val_accuracy: 0.7637 - val_loss: 0.5787
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8153 - loss: 0.4624 - val_accuracy: 0.7582 - val_loss: 0.5801
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8164 - loss: 0.4912 - val_accuracy: 0.7473 - val_loss: 0.5708
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8393 - loss: 0.4144 - val_accuracy: 0.7692 - val_loss: 0.5567
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8255 - loss: 0.4356 - val_accuracy: 0.7582 - val_loss: 0.5688
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8309 - loss: 0.4362 - val_accuracy: 0.7637 - val_loss: 0.5605
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8252 - loss: 0.4346 - val_accuracy: 0.7692 - val_loss: 0.5590
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.8633 - loss: 0.3644 - val_accuracy: 0.7857 - val_loss: 0.5566
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.8460 - loss: 0.3612 - val_accuracy: 0.7637 - val_loss: 0.5569
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8447 - loss: 0.3733 - val_accuracy: 0.7747 - val_loss: 0.5341
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Subject Subject18
# Accuracy     : 0.7747
# Precision    : 0.7755
# Recall       : 0.7747
# F1 Score     : 0.7715
# Specificity  : 0.8868
# Model for Subject Subject18 saved as /kaggle/working/subject_Subject18_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.4417 - loss: 1.1960 - val_accuracy: 0.6044 - val_loss: 0.9542
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.6591 - loss: 0.9204 - val_accuracy: 0.7088 - val_loss: 0.8090
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.6904 - loss: 0.8058 - val_accuracy: 0.7308 - val_loss: 0.7800
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7621 - loss: 0.6709 - val_accuracy: 0.7198 - val_loss: 0.7147
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7277 - loss: 0.6755 - val_accuracy: 0.7198 - val_loss: 0.7919
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7219 - loss: 0.7152 - val_accuracy: 0.7308 - val_loss: 0.7284
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7806 - loss: 0.5948 - val_accuracy: 0.7418 - val_loss: 0.6295
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7356 - loss: 0.6133 - val_accuracy: 0.7363 - val_loss: 0.6087
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7781 - loss: 0.5547 - val_accuracy: 0.7308 - val_loss: 0.5979
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8126 - loss: 0.4915 - val_accuracy: 0.7198 - val_loss: 0.6108
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8008 - loss: 0.5045 - val_accuracy: 0.7527 - val_loss: 0.5938
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8059 - loss: 0.4729 - val_accuracy: 0.7473 - val_loss: 0.5657
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.7808 - loss: 0.5000 - val_accuracy: 0.7253 - val_loss: 0.5960
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8230 - loss: 0.4384 - val_accuracy: 0.7473 - val_loss: 0.5580
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8213 - loss: 0.4482 - val_accuracy: 0.7582 - val_loss: 0.5486
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8192 - loss: 0.4396 - val_accuracy: 0.7527 - val_loss: 0.5329
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8198 - loss: 0.4247 - val_accuracy: 0.7418 - val_loss: 0.5468
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8756 - loss: 0.3548 - val_accuracy: 0.7527 - val_loss: 0.5395
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8166 - loss: 0.4217 - val_accuracy: 0.7582 - val_loss: 0.5356
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8293 - loss: 0.3732 - val_accuracy: 0.7802 - val_loss: 0.5317
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject19
# Accuracy     : 0.7802
# Precision    : 0.7641
# Recall       : 0.7802
# F1 Score     : 0.7624
# Specificity  : 0.8483
# Model for Subject Subject19 saved as /kaggle/working/subject_Subject19_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.4752 - loss: 1.1956 - val_accuracy: 0.6011 - val_loss: 0.9938
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6188 - loss: 0.9260 - val_accuracy: 0.6776 - val_loss: 0.9094
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6984 - loss: 0.8180 - val_accuracy: 0.6667 - val_loss: 0.8428
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7083 - loss: 0.7386 - val_accuracy: 0.6995 - val_loss: 0.7860
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7371 - loss: 0.7157 - val_accuracy: 0.6885 - val_loss: 0.7570
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7385 - loss: 0.7082 - val_accuracy: 0.7158 - val_loss: 0.7126
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7462 - loss: 0.6805 - val_accuracy: 0.7158 - val_loss: 0.6952
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7951 - loss: 0.6101 - val_accuracy: 0.7268 - val_loss: 0.6539
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7707 - loss: 0.6266 - val_accuracy: 0.7486 - val_loss: 0.6147
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7783 - loss: 0.5901 - val_accuracy: 0.7268 - val_loss: 0.6288
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7819 - loss: 0.5743 - val_accuracy: 0.7596 - val_loss: 0.6012
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7988 - loss: 0.5483 - val_accuracy: 0.7814 - val_loss: 0.5636
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8007 - loss: 0.5155 - val_accuracy: 0.7705 - val_loss: 0.5579
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8213 - loss: 0.5112 - val_accuracy: 0.7869 - val_loss: 0.5446
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7932 - loss: 0.5319 - val_accuracy: 0.7814 - val_loss: 0.5111
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.8281 - loss: 0.4704 - val_accuracy: 0.7760 - val_loss: 0.4921
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8077 - loss: 0.5034 - val_accuracy: 0.7923 - val_loss: 0.4803
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8212 - loss: 0.4866 - val_accuracy: 0.7814 - val_loss: 0.4638
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8457 - loss: 0.4390 - val_accuracy: 0.8415 - val_loss: 0.4376
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.8208 - loss: 0.4562 - val_accuracy: 0.8415 - val_loss: 0.4345
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#
# Subject Subject2
# Accuracy     : 0.8415
# Precision    : 0.8509
# Recall       : 0.8415
# F1 Score     : 0.8431
# Specificity  : 0.9505
# Model for Subject Subject2 saved as /kaggle/working/subject_Subject2_cnn_model.h5
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - accuracy: 0.4327 - loss: 1.2209 - val_accuracy: 0.5364 - val_loss: 0.9771
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.5661 - loss: 0.9867 - val_accuracy: 0.6545 - val_loss: 0.8584
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6358 - loss: 0.8526 - val_accuracy: 0.6500 - val_loss: 0.7852
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6341 - loss: 0.8220 - val_accuracy: 0.6591 - val_loss: 0.7573
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.6732 - loss: 0.7609 - val_accuracy: 0.7000 - val_loss: 0.7161
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7082 - loss: 0.7465 - val_accuracy: 0.6909 - val_loss: 0.6934
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6850 - loss: 0.6989 - val_accuracy: 0.6909 - val_loss: 0.6789
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.6938 - loss: 0.6806 - val_accuracy: 0.7091 - val_loss: 0.6525
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7220 - loss: 0.6308 - val_accuracy: 0.7091 - val_loss: 0.6111
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7240 - loss: 0.6071 - val_accuracy: 0.7500 - val_loss: 0.6015
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7424 - loss: 0.5772 - val_accuracy: 0.7500 - val_loss: 0.5780
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.7850 - loss: 0.5296 - val_accuracy: 0.7409 - val_loss: 0.5738
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7387 - loss: 0.5731 - val_accuracy: 0.7636 - val_loss: 0.5517
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7880 - loss: 0.5125 - val_accuracy: 0.7545 - val_loss: 0.5699
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.7954 - loss: 0.4813 - val_accuracy: 0.7773 - val_loss: 0.5308
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7470 - loss: 0.5373 - val_accuracy: 0.7455 - val_loss: 0.5745
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.7840 - loss: 0.5049 - val_accuracy: 0.7727 - val_loss: 0.5521
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8069 - loss: 0.4702 - val_accuracy: 0.7955 - val_loss: 0.5004
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8295 - loss: 0.4371 - val_accuracy: 0.7364 - val_loss: 0.5380
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.8151 - loss: 0.4233 - val_accuracy: 0.7364 - val_loss: 0.5653
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
#
# Subject Subject20
# Accuracy     : 0.7364
# Precision    : 0.7614
# Recall       : 0.7364
# F1 Score     : 0.7043
# Specificity  : 0.8217
# Model for Subject Subject20 saved as /kaggle/working/subject_Subject20_cnn_model.h5
# Epoch 1/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 0.4565 - loss: 1.2294 - val_accuracy: 0.5517 - val_loss: 0.9629
# Epoch 2/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.6027 - loss: 0.9837 - val_accuracy: 0.7044 - val_loss: 0.7730
# Epoch 3/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7111 - loss: 0.7916 - val_accuracy: 0.7340 - val_loss: 0.7031
# Epoch 4/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7052 - loss: 0.7787 - val_accuracy: 0.7340 - val_loss: 0.6758
# Epoch 5/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7168 - loss: 0.7202 - val_accuracy: 0.7586 - val_loss: 0.6392
# Epoch 6/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7080 - loss: 0.7345 - val_accuracy: 0.7586 - val_loss: 0.6275
# Epoch 7/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.7070 - loss: 0.6998 - val_accuracy: 0.7586 - val_loss: 0.6549
# Epoch 8/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7214 - loss: 0.6912 - val_accuracy: 0.7537 - val_loss: 0.5952
# Epoch 9/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7364 - loss: 0.6803 - val_accuracy: 0.7635 - val_loss: 0.5705
# Epoch 10/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.7737 - loss: 0.6110 - val_accuracy: 0.7783 - val_loss: 0.5526
# Epoch 11/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7785 - loss: 0.6011 - val_accuracy: 0.7734 - val_loss: 0.5677
# Epoch 12/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7830 - loss: 0.5689 - val_accuracy: 0.7586 - val_loss: 0.5713
# Epoch 13/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7512 - loss: 0.6116 - val_accuracy: 0.7783 - val_loss: 0.5205
# Epoch 14/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7589 - loss: 0.5976 - val_accuracy: 0.7833 - val_loss: 0.5280
# Epoch 15/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.7954 - loss: 0.5649 - val_accuracy: 0.8227 - val_loss: 0.5127
# Epoch 16/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.8026 - loss: 0.5211 - val_accuracy: 0.7931 - val_loss: 0.5091
# Epoch 17/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7931 - loss: 0.5318 - val_accuracy: 0.8374 - val_loss: 0.4809
# Epoch 18/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7942 - loss: 0.5223 - val_accuracy: 0.8128 - val_loss: 0.4992
# Epoch 19/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8110 - loss: 0.4841 - val_accuracy: 0.7980 - val_loss: 0.4997
# Epoch 20/20
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8157 - loss: 0.4708 - val_accuracy: 0.8276 - val_loss: 0.4795
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Subject Subject3
# Accuracy     : 0.8276
# Precision    : 0.8280
# Recall       : 0.8276
# F1 Score     : 0.8274
# Specificity  : 0.9169
# Model for Subject Subject3 saved as /kaggle/working/subject_Subject3_cnn_model.h5
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - accuracy: 0.5095 - loss: 1.1568 - val_accuracy: 0.6550 - val_loss: 0.8691
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6645 - loss: 0.8325 - val_accuracy: 0.6750 - val_loss: 0.7382
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6814 - loss: 0.7533 - val_accuracy: 0.7300 - val_loss: 0.6707
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7268 - loss: 0.7075 - val_accuracy: 0.7150 - val_loss: 0.6525
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7235 - loss: 0.7050 - val_accuracy: 0.7400 - val_loss: 0.6187
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7234 - loss: 0.6844 - val_accuracy: 0.7900 - val_loss: 0.5580
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.7526 - loss: 0.6350 - val_accuracy: 0.7650 - val_loss: 0.5408
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7950 - loss: 0.5354 - val_accuracy: 0.7700 - val_loss: 0.5243
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7920 - loss: 0.5591 - val_accuracy: 0.7800 - val_loss: 0.5197
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.7784 - loss: 0.5359 - val_accuracy: 0.8100 - val_loss: 0.4677
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7980 - loss: 0.5083 - val_accuracy: 0.8000 - val_loss: 0.4961
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - accuracy: 0.8088 - loss: 0.4967 - val_accuracy: 0.7850 - val_loss: 0.5136
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.8123 - loss: 0.4660 - val_accuracy: 0.8350 - val_loss: 0.4146
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.8587 - loss: 0.3999 - val_accuracy: 0.8500 - val_loss: 0.4061
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.8467 - loss: 0.4092 - val_accuracy: 0.8400 - val_loss: 0.3950
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8753 - loss: 0.3566 - val_accuracy: 0.8200 - val_loss: 0.3931
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8676 - loss: 0.3712 - val_accuracy: 0.8300 - val_loss: 0.3974
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.8805 - loss: 0.3509 - val_accuracy: 0.8400 - val_loss: 0.3938
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.8457 - loss: 0.3788 - val_accuracy: 0.8250 - val_loss: 0.3659
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8744 - loss: 0.3267 - val_accuracy: 0.8700 - val_loss: 0.3439
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Subject Subject4
# Accuracy     : 0.8700
# Precision    : 0.8746
# Recall       : 0.8700
# F1 Score     : 0.8706
# Specificity  : 0.9460
# Model for Subject Subject4 saved as /kaggle/working/subject_Subject4_cnn_model.h5
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.4519 - loss: 1.1918 - val_accuracy: 0.6212 - val_loss: 0.9098
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.6113 - loss: 0.9476 - val_accuracy: 0.6616 - val_loss: 0.8455
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.6705 - loss: 0.8378 - val_accuracy: 0.6970 - val_loss: 0.7751
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.7114 - loss: 0.8095 - val_accuracy: 0.7273 - val_loss: 0.7347
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7286 - loss: 0.7577 - val_accuracy: 0.7273 - val_loss: 0.7334
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.7433 - loss: 0.7192 - val_accuracy: 0.7424 - val_loss: 0.6742
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7460 - loss: 0.6400 - val_accuracy: 0.7727 - val_loss: 0.6581
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.7879 - loss: 0.6349 - val_accuracy: 0.7273 - val_loss: 0.6518
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7907 - loss: 0.6244 - val_accuracy: 0.7071 - val_loss: 0.6880
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7620 - loss: 0.6279 - val_accuracy: 0.7677 - val_loss: 0.5933
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7958 - loss: 0.5560 - val_accuracy: 0.7828 - val_loss: 0.5675
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7728 - loss: 0.5574 - val_accuracy: 0.7879 - val_loss: 0.5508
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7924 - loss: 0.5313 - val_accuracy: 0.7424 - val_loss: 0.6434
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.8238 - loss: 0.5097 - val_accuracy: 0.7778 - val_loss: 0.5158
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8367 - loss: 0.4755 - val_accuracy: 0.7828 - val_loss: 0.4986
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8198 - loss: 0.4859 - val_accuracy: 0.7929 - val_loss: 0.5075
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8106 - loss: 0.4727 - val_accuracy: 0.8131 - val_loss: 0.4695
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8174 - loss: 0.4637 - val_accuracy: 0.7929 - val_loss: 0.4805
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8390 - loss: 0.4179 - val_accuracy: 0.7980 - val_loss: 0.4811
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8707 - loss: 0.3825 - val_accuracy: 0.8030 - val_loss: 0.4552
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Subject Subject5
# Accuracy     : 0.8030
# Precision    : 0.7949
# Recall       : 0.8030
# F1 Score     : 0.7931
# Specificity  : 0.8811
# Model for Subject Subject5 saved as /kaggle/working/subject_Subject5_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - accuracy: 0.4875 - loss: 1.2090 - val_accuracy: 0.6264 - val_loss: 1.0079
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6270 - loss: 0.9778 - val_accuracy: 0.6538 - val_loss: 0.9062
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.6898 - loss: 0.8380 - val_accuracy: 0.6758 - val_loss: 0.8947
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.6879 - loss: 0.8396 - val_accuracy: 0.6758 - val_loss: 0.8606
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7157 - loss: 0.7645 - val_accuracy: 0.6758 - val_loss: 0.8353
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7208 - loss: 0.7493 - val_accuracy: 0.7143 - val_loss: 0.8249
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7463 - loss: 0.7002 - val_accuracy: 0.7143 - val_loss: 0.8096
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.7392 - loss: 0.7008 - val_accuracy: 0.7418 - val_loss: 0.7725
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7832 - loss: 0.6639 - val_accuracy: 0.7033 - val_loss: 0.7747
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.7373 - loss: 0.6919 - val_accuracy: 0.7308 - val_loss: 0.7472
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.7711 - loss: 0.5972 - val_accuracy: 0.7308 - val_loss: 0.7334
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7778 - loss: 0.5755 - val_accuracy: 0.6978 - val_loss: 0.7329
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7919 - loss: 0.5755 - val_accuracy: 0.7088 - val_loss: 0.7594
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.7544 - loss: 0.6373 - val_accuracy: 0.7253 - val_loss: 0.6896
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8042 - loss: 0.5140 - val_accuracy: 0.7527 - val_loss: 0.7003
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8121 - loss: 0.4819 - val_accuracy: 0.7198 - val_loss: 0.7087
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7748 - loss: 0.5442 - val_accuracy: 0.7308 - val_loss: 0.6763
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7974 - loss: 0.4854 - val_accuracy: 0.7473 - val_loss: 0.6821
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8337 - loss: 0.4729 - val_accuracy: 0.7637 - val_loss: 0.6622
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8269 - loss: 0.4371 - val_accuracy: 0.7418 - val_loss: 0.6632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject6
# Accuracy     : 0.7418
# Precision    : 0.7442
# Recall       : 0.7418
# F1 Score     : 0.7254
# Specificity  : 0.7925
# Model for Subject Subject6 saved as /kaggle/working/subject_Subject6_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - accuracy: 0.4756 - loss: 1.1762 - val_accuracy: 0.5525 - val_loss: 0.9142
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.6010 - loss: 0.8895 - val_accuracy: 0.6685 - val_loss: 0.7992
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.6696 - loss: 0.8497 - val_accuracy: 0.6961 - val_loss: 0.7824
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.6656 - loss: 0.7722 - val_accuracy: 0.7293 - val_loss: 0.7520
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7359 - loss: 0.7672 - val_accuracy: 0.7403 - val_loss: 0.7421
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7441 - loss: 0.7295 - val_accuracy: 0.7403 - val_loss: 0.7096
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.7607 - loss: 0.6918 - val_accuracy: 0.7127 - val_loss: 0.7106
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7441 - loss: 0.6687 - val_accuracy: 0.7127 - val_loss: 0.6665
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7866 - loss: 0.6231 - val_accuracy: 0.7680 - val_loss: 0.6528
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7816 - loss: 0.6189 - val_accuracy: 0.7790 - val_loss: 0.6206
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.7926 - loss: 0.5792 - val_accuracy: 0.7293 - val_loss: 0.6030
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7594 - loss: 0.5825 - val_accuracy: 0.7624 - val_loss: 0.5604
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.8164 - loss: 0.5197 - val_accuracy: 0.7624 - val_loss: 0.5536
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.8342 - loss: 0.4870 - val_accuracy: 0.7569 - val_loss: 0.5506
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8407 - loss: 0.4594 - val_accuracy: 0.7845 - val_loss: 0.5370
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8381 - loss: 0.4660 - val_accuracy: 0.7956 - val_loss: 0.5716
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.8307 - loss: 0.4661 - val_accuracy: 0.7845 - val_loss: 0.5025
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8506 - loss: 0.4226 - val_accuracy: 0.7956 - val_loss: 0.5140
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.8668 - loss: 0.4101 - val_accuracy: 0.7901 - val_loss: 0.5100
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8573 - loss: 0.3838 - val_accuracy: 0.8066 - val_loss: 0.5179
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Subject Subject7
# Accuracy     : 0.8066
# Precision    : 0.8119
# Recall       : 0.8066
# F1 Score     : 0.8083
# Specificity  : 0.9329
# Model for Subject Subject7 saved as /kaggle/working/subject_Subject7_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - accuracy: 0.4985 - loss: 1.2049 - val_accuracy: 0.5220 - val_loss: 1.0600
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.5660 - loss: 0.9985 - val_accuracy: 0.6484 - val_loss: 0.8506
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.6900 - loss: 0.7558 - val_accuracy: 0.6923 - val_loss: 0.7256
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.7303 - loss: 0.6561 - val_accuracy: 0.7143 - val_loss: 0.6693
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.7378 - loss: 0.6305 - val_accuracy: 0.7088 - val_loss: 0.6837
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7696 - loss: 0.5791 - val_accuracy: 0.7253 - val_loss: 0.6209
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7746 - loss: 0.5650 - val_accuracy: 0.7637 - val_loss: 0.6005
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7654 - loss: 0.5351 - val_accuracy: 0.7143 - val_loss: 0.6072
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8086 - loss: 0.4978 - val_accuracy: 0.7253 - val_loss: 0.6306
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.7719 - loss: 0.5262 - val_accuracy: 0.7747 - val_loss: 0.5636
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8212 - loss: 0.4644 - val_accuracy: 0.7802 - val_loss: 0.5770
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.7947 - loss: 0.4756 - val_accuracy: 0.7747 - val_loss: 0.5648
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.8093 - loss: 0.4519 - val_accuracy: 0.7692 - val_loss: 0.5540
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.8165 - loss: 0.4343 - val_accuracy: 0.7308 - val_loss: 0.5960
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8024 - loss: 0.4312 - val_accuracy: 0.7582 - val_loss: 0.5563
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8363 - loss: 0.4367 - val_accuracy: 0.7418 - val_loss: 0.5794
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.8382 - loss: 0.3959 - val_accuracy: 0.7857 - val_loss: 0.5413
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.8624 - loss: 0.3575 - val_accuracy: 0.7802 - val_loss: 0.5636
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8521 - loss: 0.3690 - val_accuracy: 0.7857 - val_loss: 0.5499
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8592 - loss: 0.3571 - val_accuracy: 0.7637 - val_loss: 0.5695
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Subject Subject8
# Accuracy     : 0.7637
# Precision    : 0.7651
# Recall       : 0.7637
# F1 Score     : 0.7607
# Specificity  : 0.8691
# Model for Subject Subject8 saved as /kaggle/working/subject_Subject8_cnn_model.h5
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.5279 - loss: 1.0982 - val_accuracy: 0.6429 - val_loss: 0.8204
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6590 - loss: 0.8421 - val_accuracy: 0.7253 - val_loss: 0.7165
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.6801 - loss: 0.7632 - val_accuracy: 0.7308 - val_loss: 0.6725
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7136 - loss: 0.7364 - val_accuracy: 0.7418 - val_loss: 0.6378
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7469 - loss: 0.6230 - val_accuracy: 0.7418 - val_loss: 0.6401
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.7648 - loss: 0.6128 - val_accuracy: 0.7198 - val_loss: 0.6274
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7753 - loss: 0.5911 - val_accuracy: 0.7747 - val_loss: 0.5782
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.7620 - loss: 0.5965 - val_accuracy: 0.7308 - val_loss: 0.6209
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7537 - loss: 0.6265 - val_accuracy: 0.7473 - val_loss: 0.5436
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8009 - loss: 0.5009 - val_accuracy: 0.7857 - val_loss: 0.5274
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.8327 - loss: 0.4659 - val_accuracy: 0.7747 - val_loss: 0.4844
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8007 - loss: 0.4672 - val_accuracy: 0.7637 - val_loss: 0.5068
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8150 - loss: 0.4809 - val_accuracy: 0.8132 - val_loss: 0.4599
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.8703 - loss: 0.3824 - val_accuracy: 0.7857 - val_loss: 0.5024
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8598 - loss: 0.4014 - val_accuracy: 0.8462 - val_loss: 0.4092
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.8517 - loss: 0.3779 - val_accuracy: 0.7967 - val_loss: 0.4551
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8656 - loss: 0.3232 - val_accuracy: 0.8407 - val_loss: 0.3874
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8815 - loss: 0.3008 - val_accuracy: 0.8516 - val_loss: 0.4154
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8875 - loss: 0.3307 - val_accuracy: 0.8187 - val_loss: 0.4218
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8901 - loss: 0.3056 - val_accuracy: 0.8297 - val_loss: 0.4121
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Subject Subject9
# Accuracy     : 0.8297
# Precision    : 0.8332
# Recall       : 0.8297
# F1 Score     : 0.8297
# Specificity  : 0.9115
# Model for Subject Subject9 saved as /kaggle/working/subject_Subject9_cnn_model.h5
#
# === Summary Metrics ===
#
# === Per-Subject Metrics ===
# Average Per-Subject Accuracy: 0.8071079963808115
# Average Per-Subject Precision: 0.8077630473249702
# Average Per-Subject Recall: 0.8071079963808115
# Average Per-Subject F1 Score: 0.7984748665008139
# Average Per-Subject Specificity: 0.8865873653470231
